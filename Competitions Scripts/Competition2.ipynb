# %% [markdown]
# ![Imgur](https://i.imgur.com/SB15XHN.png)
#
# ## ①　Introduction
# This is an information about a golf course weather and management conditions.
#
# 🎯　Your goal is to make a prediction of the daily spending of that golf course.
#
# You are free to add/remove sections and made any modification to this notebook. Only your final submission will be graded. This notebook will not be graded.
#
# In this notebook, you will mainly work on Section ⑤ (Preprocessing) and Section ⑦ (Model Building).

# %% [markdown]
# ## ②　Setting Up the Environment
# These are all the libraries used in the lecture.

# %%
# Basic Libraries (L1)
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy  as np
import warnings
warnings.filterwarnings('ignore')

# Data Preprocessing (L2)
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler, OneHotEncoder

# Data Exploration (L3)
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import randint, norm, lognorm, expon, uniform, gamma
from scipy.stats import probplot, chi2_contingency

# Basic Classifiers & Regressors (L4-5)
from sklearn.linear_model import LogisticRegression,     LinearRegression
from sklearn.linear_model import Lasso, LassoCV,         ElasticNet, ElasticNetCV
from sklearn.naive_bayes  import BernoulliNB,            GaussianNB
from sklearn.neighbors    import KNeighborsClassifier,   KNeighborsRegressor
from sklearn.dummy        import DummyClassifier,        DummyRegressor
from sklearn.tree         import DecisionTreeClassifier, DecisionTreeRegressor, plot_tree
from sklearn.svm          import SVC,                    SVR

# Ensemble Classifiers & Regressors (L6)
from sklearn.ensemble     import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.ensemble     import RandomForestClassifier,     RandomForestRegressor
from sklearn.ensemble     import StackingClassifier,         StackingRegressor
from sklearn.ensemble     import AdaBoostClassifier,         AdaBoostRegressor
from sklearn.ensemble     import BaggingClassifier,          BaggingRegressor
from sklearn.ensemble     import VotingClassifier,           VotingRegressor
# from catboost             import CatBoostClassifier,         CatBoostRegressor
# import lightgbm as lgb
# import xgboost  as xgb

# Classification & Regression Metrics (L7)
from sklearn.metrics      import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics      import confusion_matrix
from sklearn.metrics      import roc_curve, roc_auc_score

from sklearn.metrics      import mean_absolute_error, mean_absolute_percentage_error
from sklearn.metrics      import mean_squared_error, mean_squared_log_error
from sklearn.metrics      import r2_score

# Model Calibration (L7)
from sklearn.calibration  import calibration_curve
from sklearn.metrics      import brier_score_loss, log_loss

# Model Selection & Validation (L7)
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import KFold, StratifiedKFold, LeaveOneOut

# Hyperparameter Optimization (L7)
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Multiclass Classification (L8)
from sklearn.multiclass      import OneVsOneClassifier,    OneVsRestClassifier
from sklearn.metrics         import classification_report, precision_recall_fscore_support

# Model Weighting (L8)
from sklearn.utils.class_weight import compute_sample_weight

# Resampling Techniques (L8)
from imblearn.over_sampling  import RandomOverSampler,  SMOTE,    ADASYN
from imblearn.under_sampling import RandomUnderSampler, NearMiss, TomekLinks
from imblearn.combine        import SMOTEENN

# Pipeline (L9)
from imblearn.pipeline       import make_pipeline, Pipeline
from sklearn.compose         import ColumnTransformer

# Feature Selection (L9)
from sklearn.feature_selection import SelectKBest, SelectPercentile, SelectFromModel
from sklearn.feature_selection import f_classif, f_regression, chi2
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression
from sklearn.feature_selection import RFE, RFECV, SequentialFeatureSelector

# Dimensionality Reduction (L9)
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition         import PCA, KernelPCA
from sklearn.manifold              import TSNE

# %% [markdown]
# ## ③　Loading Training Dataset

# %%
# Load the train dataset
train_url = "/kaggle/input/prediction-of-golf-course-spending/train.csv"
df_train = pd.read_csv(train_url, index_col=0)

target_col = 'Spending'

X_train, y_train = df_train.drop(target_col, axis=1), df_train[target_col]

df_train
# Out:
#             Season  DayLength  Weekend  Temperature  ChanceOfRain  \
# Date
# 2011-01-01  Winter       8.99        1        -1.22         29.77
# 2011-01-02  Winter       9.01        1        -1.44         92.61
# 2011-01-03  Winter       9.02        0        -1.46          0.50
# 2011-01-04  Winter       9.04        0        -0.40          0.00
# 2011-01-05  Winter       9.06        0        -1.24          0.00
# ...            ...        ...      ...          ...           ...
# 2021-12-27  Winter       8.94        0        -1.61         45.08
# 2021-12-28  Winter       8.95        0        -1.13          0.85
# 2021-12-29  Winter       8.96        0         0.18          0.00
# 2021-12-30  Winter       8.97        0         0.08         38.83
# 2021-12-31  Winter       8.98        0        -1.75          0.31
#
#             AtmosphericPressure  WindSpeed  Evaporation  WindDirection  \
# Date
# 2011-01-01              1006.61      11.06         3.16         287.48
# 2011-01-02               996.12      18.78         2.37         146.61
# 2011-01-03              1012.61       8.06         2.96          52.59
# 2011-01-04              1016.08       6.76         5.02         286.07
# 2011-01-05              1019.57       4.31         2.67         326.05
# ...                         ...        ...          ...            ...
# 2021-12-27              1003.67      12.31         2.19          82.66
# 2021-12-28              1009.78       9.17         3.06         349.48
# 2021-12-29              1016.18       4.74         3.07         268.00
# 2021-12-30              1003.65      12.28         3.46          22.64
# 2021-12-31              1013.40       7.86         2.70         349.48
#
#             Humidity  CloudCover  Precipitation  Visibility  DewPoint  \
# Date
# 2011-01-01     44.51       36.76           4.78        1.08      6.32
# 2011-01-02     53.34       51.17           9.46        0.67      7.87
# 2011-01-03     34.90       38.91           3.66        1.43      4.55
# 2011-01-04     30.28       10.44           1.08        4.74      3.03
# 2011-01-05     23.60       38.84           2.92        2.03      2.67
# ...              ...         ...            ...         ...       ...
# 2021-12-27     43.98       37.26           5.40        1.03      6.02
# 2021-12-28     38.00       31.44           3.39        1.36      5.09
# 2021-12-29     33.44       38.80           1.76        2.10      3.84
# 2021-12-30     47.48       31.47           4.70        1.04      7.25
# 2021-12-31     32.15       36.31           3.10        1.58      3.06
#
#             UVIndex  WindGusts  LightningStrikes  AirQualityIndex  \
# Date
# 2011-01-01        2      24.57                 1             4.98
# 2011-01-02        1      41.48                 1             1.90
# 2011-01-03        2      17.04                 1             8.24
# 2011-01-04        3      12.32                 1             9.96
# 2011-01-05        2       9.11                 0            13.66
# ...             ...        ...               ...              ...
# 2021-12-27        2      29.88                 1             4.46
# 2021-12-28        2      20.79                 1             6.55
# 2021-12-29        2      12.84                 1            14.00
# 2021-12-30        2      30.43                 1             4.44
# 2021-12-31        2      15.40                 1             8.37
#
#             SolarRadiation  SoilMoisture  BarometricTrend  GrassGrowth  \
# Date
# 2011-01-01            2.69         59.05            -0.38         2.49
# 2011-01-02            1.84         74.05             0.27         4.09
# 2011-01-03            4.46         47.66            -0.46         2.78
# 2011-01-04            3.76         19.26            -0.46         0.42
# 2011-01-05            7.94         35.63            -1.33         3.61
# ...                    ...           ...              ...          ...
# 2021-12-27            2.03         61.55            -0.71         2.55
# 2021-12-28            3.34         50.18            -0.65         2.04
# 2021-12-29            7.19         32.82            -2.05         3.33
# 2021-12-30            1.68         60.48            -0.48         1.99
# 2021-12-31            4.38         44.65            -0.17         2.08
#
#             FrostOccurrence  LeafWetnessDuration  SolarNoonTime  \
# Date
# 2011-01-01                1                 0.57           6.62
# 2011-01-02                1                 0.87           6.67
# 2011-01-03                1                 0.26           6.70
# 2011-01-04                1                 0.17           6.80
# 2011-01-05                1                 0.15           6.89
# ...                     ...                  ...            ...
# 2021-12-27                1                 0.53           6.38
# 2021-12-28                1                 0.33           6.41
# 2021-12-29                0                 0.23           6.48
# 2021-12-30                0                 0.66           6.52
# 2021-12-31                1                 0.21           6.54
#
#             AirTempVariation  GroundTemperature  RelativeHumidity  \
# Date
# 2011-01-01              0.80              -4.74             21.85
# 2011-01-02              0.84              -6.76             24.75
# 2011-01-03              0.94              -1.91             17.76
# 2011-01-04              0.96              -2.30             17.14
# 2011-01-05              0.86               5.01             14.33
# ...                      ...                ...               ...
# 2021-12-27              0.62              -5.99             20.11
# 2021-12-28              0.71              -3.15             18.38
# 2021-12-29              0.95               5.57             19.14
# 2021-12-30              0.97              -5.40             23.89
# 2021-12-31              0.70              -2.03             16.22
#
#             AtmosphericStability  TotalRainfall  MaxWindSpeed  SoilAcidity  \
# Date
# 2011-01-01                 -0.22           4.61          9.43         6.92
# 2011-01-02                  0.20           9.51         12.78         7.39
# 2011-01-03                 -0.62           3.44          6.95         6.71
# 2011-01-04                 -0.47           0.98         10.76         5.82
# 2011-01-05                 -1.06           2.24          6.30         6.42
# ...                          ...            ...           ...          ...
# 2021-12-27                 -0.45           5.08          8.36         7.00
# 2021-12-28                 -0.74           3.19          5.92         6.70
# 2021-12-29                 -2.18           1.60          1.46         6.16
# 2021-12-30                 -0.49           4.51          8.66         6.94
# 2021-12-31                  0.04           3.02         10.63         6.56
#
#             SunshineDuration  WaterTableDepth  PollutionIndex  SpecialEvents  \
# Date
# 2011-01-01              4.06             2.75            7.65              0
# 2011-01-02              4.76             4.72            7.07              0
# 2011-01-03              5.30             2.19           25.53              0
# 2011-01-04              2.94             1.06           24.02              0
# 2011-01-05              6.13             1.41            1.26              0
# ...                      ...              ...             ...            ...
# 2021-12-27              3.70             3.01            9.48              0
# 2021-12-28              4.11             2.26            5.84              0
# 2021-12-29              6.03             1.10           17.20              0
# 2021-12-30              2.84             2.80            8.43              0
# 2021-12-31              5.09             2.01            9.40              0
#
#             DailyPlayers  CourseCondition  EquipmentUsage  MaintenanceLevel  \
# Date
# 2011-01-01            42             0.35            0.47                 3
# 2011-01-02            24             0.03            0.17                 3
# 2011-01-03            32             0.57            0.30                 2
# 2011-01-04            47             0.72            0.54                 2
# 2011-01-05            39             0.82            0.42                 2
# ...                  ...              ...             ...               ...
# 2021-12-27            36             0.22            0.36                 2
# 2021-12-28            32             0.47            0.31                 2
# 2021-12-29            40             0.95            0.46                 2
# 2021-12-30            31             0.23            0.28                 2
# 2021-12-31            30             0.59            0.26                 2
#
#             GreenSpeed  StaffingLevel  ProShopSales  FoodBeverageSales  \
# Date
# 2011-01-01        9.77             13        619.79             758.79
# 2011-01-02       10.64              8        441.47             527.83
# 2011-01-03        9.10             10        532.06             636.99
# 2011-01-04        7.73             14        629.55             813.31
# 2011-01-05        8.39             12        597.07             728.76
# ...                ...            ...           ...                ...
# 2021-12-27        9.85             12        559.92             697.45
# 2021-12-28        9.21             10        525.18             627.06
# 2021-12-29        8.35             13        596.82             736.18
# 2021-12-30        9.76             10        519.75             630.10
# 2021-12-31        9.00              9        505.77             602.60
#
#             CustomerSatisfaction  WaterUsage  IrrigationEfficiency  \
# Date
# 2011-01-01                  2.34       65.88                  0.34
# 2011-01-02                  1.07       58.75                  0.36
# 2011-01-03                  3.32       69.61                  0.21
# 2011-01-04                  3.82      100.73                  0.39
# 2011-01-05                  4.26       54.14                  0.15
# ...                          ...         ...                   ...
# 2021-12-27                  1.89       40.06                  0.36
# 2021-12-28                  2.84       65.72                  0.32
# 2021-12-29                  4.80       62.88                  0.35
# 2021-12-30                  1.84       73.52                  0.45
# 2021-12-31                  3.44       49.53                  0.24
#
#             PestControl  GrassHealth  DrivingRangeUsage  GolfCartMaintenance  \
# Date
# 2011-01-01            0         0.15               0.47                    3
# 2011-01-02            0         0.34               0.18                    1
# 2011-01-03            0         0.16               0.31                    1
# 2011-01-04            2         0.01               0.57                    3
# 2011-01-05            0         0.29               0.43                    0
# ...                 ...          ...                ...                  ...
# 2021-12-27            1         0.13               0.37                    0
# 2021-12-28            1         0.07               0.30                    3
# 2021-12-29            0         0.22               0.43                    2
# 2021-12-30            1         0.09               0.29                    0
# 2021-12-31            0         0.11               0.26                    1
#
#             ClubhouseTraffic  PracticeGreenUsage  LockerRoomUsage  \
# Date
# 2011-01-01                58                0.64             0.58
# 2011-01-02                47                0.29             0.24
# 2011-01-03                52                0.43             0.36
# 2011-01-04                61                0.73             0.63
# 2011-01-05                55                0.56             0.52
# ...                      ...                 ...              ...
# 2021-12-27                54                0.52             0.46
# 2021-12-28                51                0.43             0.34
# 2021-12-29                55                0.59             0.52
# 2021-12-30                51                0.41             0.35
# 2021-12-31                50                0.39             0.33
#
#             MerchandiseSales  OnlineBookingRate  LandscapingQuality  \
# Date
# 2011-01-01            360.05               0.90                0.82
# 2011-01-02            271.14               0.63                0.86
# 2011-01-03            314.04               0.76                0.39
# 2011-01-04            368.63               0.93                0.65
# 2011-01-05            351.24               0.86                0.31
# ...                      ...                ...                 ...
# 2021-12-27            328.02               0.84                0.44
# 2021-12-28            313.25               0.78                0.51
# 2021-12-29            349.78               0.88                0.59
# 2021-12-30            312.21               0.76                0.60
# 2021-12-31            307.29               0.75                0.37
#
#             TournamentPreparations  GolfCourseVisitorCount  \
# Date
# 2011-01-01                       0                      90
# 2011-01-02                       0                      76
# 2011-01-03                       1                      83
# 2011-01-04                       3                      94
# 2011-01-05                       1                      87
# ...                            ...                     ...
# 2021-12-27                       0                      85
# 2021-12-28                       2                      81
# 2021-12-29                       1                      87
# 2021-12-30                       1                      81
# 2021-12-31                       0                      81
#
#             TeeTimeUtilization  CourseWetnessLevel  GolfLessonAttendance  \
# Date
# 2011-01-01               83.23                0.39                    25
# 2011-01-02               47.40                0.61                    18
# 2011-01-03               65.73                0.35                    20
# 2011-01-04               88.14                0.18                    28
# 2011-01-05               78.65                0.32                    24
# ...                        ...                 ...                   ...
# 2021-12-27               74.61                0.46                    23
# 2021-12-28               64.52                0.33                    21
# 2021-12-29               79.07                0.26                    24
# 2021-12-30               66.13                0.39                    21
# 2021-12-31               63.93                0.33                    20
#
#             MerchandiseInventoryTurnover  ParkingLotUsage  CaddieServiceUsage  \
# Date
# 2011-01-01                          1.82            76.72                0.67
# 2011-01-02                          0.92            40.23                0.29
# 2011-01-03                          1.38            60.42                0.45
# 2011-01-04                          1.88            84.24                0.73
# 2011-01-05                          1.75            70.01                0.61
# ...                                  ...              ...                 ...
# 2021-12-27                          1.51            63.01                0.51
# 2021-12-28                          1.34            53.24                0.43
# 2021-12-29                          1.74            71.36                0.59
# 2021-12-30                          1.39            51.64                0.41
# 2021-12-31                          1.32            52.90                0.40
#
#             RestaurantBarRevenue  InflationRate2011  Spending
# Date
# 2011-01-01               1287.99          -0.000094   1037.49
# 2011-01-02                874.09           0.000055   1355.80
# 2011-01-03                832.14           0.001808    757.05
# 2011-01-04                976.23           0.000199    362.70
# 2011-01-05               1116.69           0.002617    561.60
# ...                          ...                ...       ...
# 2021-12-27                927.78           0.199259    660.51
# 2021-12-28                924.05           0.200693    774.02
# 2021-12-29                663.30           0.202556    884.20
# 2021-12-30                830.41           0.199159    642.89
# 2021-12-31                429.33           0.201271    895.49
#
# [4018 rows x 68 columns]

# %% [markdown]
# ## ④　Exploratory Data Analysis

# %%
# Perform EDA here if you want.
print(df_train.info())
df_train.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4018 entries, 2011-01-01 to 2021-12-31
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Season                        4018 non-null   object
#  1   DayLength                     4018 non-null   float64
#  2   Weekend                       4018 non-null   int64
#  3   Temperature                   4018 non-null   float64
#  4   ChanceOfRain                  4018 non-null   float64
#  5   AtmosphericPressure           4018 non-null   float64
#  6   WindSpeed                     4018 non-null   float64
#  7   Evaporation                   4018 non-null   float64
#  8   WindDirection                 4018 non-null   float64
#  9   Humidity                      4018 non-null   float64
#  10  CloudCover                    4018 non-null   float64
#  11  Precipitation                 4018 non-null   float64
#  12  Visibility                    4018 non-null   float64
#  13  DewPoint                      4018 non-null   float64
#  14  UVIndex                       4018 non-null   int64
#  15  WindGusts                     4018 non-null   float64
#  16  LightningStrikes              4018 non-null   int64
#  17  AirQualityIndex               4018 non-null   float64
#  18  SolarRadiation                4018 non-null   float64
#  19  SoilMoisture                  4018 non-null   float64
#  20  BarometricTrend               4018 non-null   float64
#  21  GrassGrowth                   4018 non-null   float64
#  22  FrostOccurrence               4018 non-null   int64
#  23  LeafWetnessDuration           4018 non-null   float64
#  24  SolarNoonTime                 4018 non-null   float64
#  25  AirTempVariation              4018 non-null   float64
#  26  GroundTemperature             4018 non-null   float64
#  27  RelativeHumidity              4018 non-null   float64
#  28  AtmosphericStability          4018 non-null   float64
#  29  TotalRainfall                 4018 non-null   float64
#  30  MaxWindSpeed                  4018 non-null   float64
#  31  SoilAcidity                   4018 non-null   float64
#  32  SunshineDuration              4018 non-null   float64
#  33  WaterTableDepth               4018 non-null   float64
#  34  PollutionIndex                4018 non-null   float64
#  35  SpecialEvents                 4018 non-null   int64
#  36  DailyPlayers                  4018 non-null   int64
#  37  CourseCondition               4018 non-null   float64
#  38  EquipmentUsage                4018 non-null   float64
#  39  MaintenanceLevel              4018 non-null   int64
#  40  GreenSpeed                    4018 non-null   float64
#  41  StaffingLevel                 4018 non-null   int64
#  42  ProShopSales                  4018 non-null   float64
#  43  FoodBeverageSales             4018 non-null   float64
#  44  CustomerSatisfaction          4018 non-null   float64
#  45  WaterUsage                    4018 non-null   float64
#  46  IrrigationEfficiency          4018 non-null   float64
#  47  PestControl                   4018 non-null   int64
#  48  GrassHealth                   4018 non-null   float64
#  49  DrivingRangeUsage             4018 non-null   float64
#  50  GolfCartMaintenance           4018 non-null   int64
#  51  ClubhouseTraffic              4018 non-null   int64
#  52  PracticeGreenUsage            4018 non-null   float64
#  53  LockerRoomUsage               4018 non-null   float64
#  54  MerchandiseSales              4018 non-null   float64
#  55  OnlineBookingRate             4018 non-null   float64
#  56  LandscapingQuality            4018 non-null   float64
#  57  TournamentPreparations        4018 non-null   int64
#  58  GolfCourseVisitorCount        4018 non-null   int64
#  59  TeeTimeUtilization            4018 non-null   float64
#  60  CourseWetnessLevel            4018 non-null   float64
#  61  GolfLessonAttendance          4018 non-null   int64
#  62  MerchandiseInventoryTurnover  4018 non-null   float64
#  63  ParkingLotUsage               4018 non-null   float64
#  64  CaddieServiceUsage            4018 non-null   float64
#  65  RestaurantBarRevenue          4018 non-null   float64
#  66  InflationRate2011             4018 non-null   float64
#  67  Spending                      4018 non-null   float64
# dtypes: float64(53), int64(14), object(1)
# memory usage: 2.1+ MB
# None
#          DayLength      Weekend  Temperature  ChanceOfRain  \
# count  4018.000000  4018.000000  4018.000000   4018.000000
# mean     12.209821     0.285714     9.724793     23.876799
# std       2.234768     0.451810     9.419895     32.491773
# min       8.920000     0.000000    -7.430000      0.000000
# 25%      10.050000     0.000000     0.732500      0.000000
# 50%      12.235000     0.000000     9.865000      0.910000
# 75%      14.380000     1.000000    18.467500     49.175000
# max      15.430000     1.000000    29.390000     99.840000
#
#        AtmosphericPressure    WindSpeed  Evaporation  WindDirection  \
# count          4018.000000  4018.000000  4018.000000    4018.000000
# mean           1013.222698     8.958484     9.895560     181.759878
# std               9.860262     4.617397     7.054592     104.305728
# min             976.060000     0.270000     0.090000       0.260000
# 25%            1006.522500     5.470000     4.862500      90.457500
# 50%            1013.225000     8.450000     8.310000     182.255000
# 75%            1020.010000    11.870000    13.157500     271.502500
# max            1047.680000    32.180000    58.260000     360.000000
#
#           Humidity   CloudCover  Precipitation   Visibility     DewPoint  \
# count  4018.000000  4018.000000    4018.000000  4018.000000  4018.000000
# mean     60.088823    50.105007       6.004619     1.143835     9.982524
# std      20.176069    22.085891       4.183233     0.622029     5.085232
# min       3.650000     1.330000       0.040000     0.140000    -7.220000
# 25%      45.595000    33.035000       2.900000     0.710000     6.570000
# 50%      61.390000    50.365000       5.090000     1.000000     9.980000
# 75%      75.907500    67.637500       8.070000     1.420000    13.290000
# max      99.270000    98.580000      32.370000     5.730000    28.730000
#
#            UVIndex    WindGusts  LightningStrikes  AirQualityIndex  \
# count  4018.000000  4018.000000       4018.000000      4018.000000
# mean      2.961424    17.917008          2.981085         9.399826
# std       1.686614    12.249006          1.727702         7.397384
# min       0.000000     0.110000          0.000000         0.530000
# 25%       2.000000     8.470000          2.000000         4.570000
# 50%       3.000000    15.595000          3.000000         7.370000
# 75%       4.000000    24.845000          4.000000        11.760000
# max      12.000000    79.610000         11.000000       131.880000
#
#        SolarRadiation  SoilMoisture  BarometricTrend  GrassGrowth  \
# count     4018.000000   4018.000000      4018.000000  4018.000000
# mean         6.098681     62.586565         0.014587     5.972934
# std          4.317412     16.105858         0.981916     3.417313
# min          0.030000      6.160000        -3.300000     0.310000
# 25%          2.960000     51.425000        -0.680000     3.420000
# 50%          5.140000     63.440000         0.040000     5.310000
# 75%          8.187500     74.737500         0.697500     7.840000
# max         34.730000     97.350000         3.510000    22.270000
#
#        FrostOccurrence  LeafWetnessDuration  SolarNoonTime  AirTempVariation  \
# count      4018.000000          4018.000000    4018.000000       4018.000000
# mean          0.214286             2.005398      11.952454          2.871018
# std           0.410377             2.032099       3.503898          1.607060
# min           0.000000             0.000000       6.000000          0.050000
# 25%           0.000000             0.580000       8.880000          1.630000
# 50%           0.000000             1.410000      12.000000          2.640000
# 75%           0.000000             2.760000      15.030000          3.920000
# max           1.000000            22.910000      18.000000          8.590000
#
#        GroundTemperature  RelativeHumidity  AtmosphericStability  \
# count        4018.000000       4018.000000           4018.000000
# mean            9.692827         39.805052              0.012359
# std             9.606616         19.899321              0.983785
# min           -10.610000          0.560000             -3.560000
# 25%             0.792500         24.242500             -0.660000
# 50%             9.480000         37.970000              0.020000
# 75%            18.247500         53.927500              0.680000
# max            32.080000         97.970000              3.860000
#
#        TotalRainfall  MaxWindSpeed  SoilAcidity  SunshineDuration  \
# count    4018.000000   4018.000000  4018.000000       4018.000000
# mean        5.882972     13.254281     7.000102          6.009734
# std         4.223931      6.835840     0.493492          2.316010
# min         0.060000      0.090000     5.240000          2.010000
# 25%         2.780000      8.020000     6.660000          4.000000
# 50%         4.910000     12.495000     7.000000          6.040000
# 75%         7.840000     17.610000     7.330000          8.000000
# max        27.710000     47.130000     8.820000         10.000000
#
#        WaterTableDepth  PollutionIndex  SpecialEvents  DailyPlayers  \
# count      4018.000000     4018.000000    4018.000000   4018.000000
# mean          3.079572        9.358564       0.028123     29.598805
# std           1.615904        7.414271       0.165346     11.159616
# min           0.430000        0.490000       0.000000      0.000000
# 25%           1.940000        4.572500       0.000000     22.000000
# 50%           2.740000        7.400000       0.000000     30.000000
# 75%           3.830000       11.680000       0.000000     37.000000
# max          15.990000       85.830000       1.000000     70.000000
#
#        CourseCondition  EquipmentUsage  MaintenanceLevel   GreenSpeed  \
# count      4018.000000     4018.000000       4018.000000  4018.000000
# mean          0.501575        0.283848          2.001244     9.994652
# std           0.289911        0.160739          0.773438     0.998671
# min           0.000000        0.000000          1.000000     6.720000
# 25%           0.250000        0.160000          1.000000     9.320000
# 50%           0.500000        0.260000          2.000000    10.000000
# 75%           0.760000        0.390000          3.000000    10.670000
# max           1.000000        0.870000          3.000000    14.220000
#
#        StaffingLevel  ProShopSales  FoodBeverageSales  CustomerSatisfaction  \
# count    4018.000000   4018.000000        4018.000000           4018.000000
# mean        9.475859    499.841979         604.847982              3.012688
# std         2.843882    102.075562         152.740360              1.159374
# min         5.000000    132.120000          16.620000              1.000000
# 25%         7.000000    428.785000         503.002500              2.000000
# 50%         9.000000    500.295000         603.725000              3.040000
# 75%        12.000000    570.812500         707.817500              4.010000
# max        14.000000    868.620000        1156.770000              5.000000
#
#        WaterUsage  IrrigationEfficiency  PestControl  GrassHealth  \
# count  4018.00000           4018.000000  4018.000000  4018.000000
# mean    200.43773              0.499530     1.291190     0.496299
# std     141.23657              0.288933     1.101214     0.287042
# min       2.52000              0.000000     0.000000     0.000000
# 25%      96.77000              0.250000     0.000000     0.250000
# 50%     168.23000              0.500000     1.000000     0.490000
# 75%     267.37000              0.750000     2.000000     0.740000
# max    1084.49000              1.000000     3.000000     1.000000
#
#        DrivingRangeUsage  GolfCartMaintenance  ClubhouseTraffic  \
# count        4018.000000          4018.000000       4018.000000
# mean            0.283771             1.025884         49.836984
# std             0.159312             1.005252          7.033265
# min             0.000000             0.000000         27.000000
# 25%             0.160000             0.000000         45.000000
# 50%             0.260000             1.000000         50.000000
# 75%             0.390000             2.000000         54.000000
# max             0.900000             3.000000         74.000000
#
#        PracticeGreenUsage  LockerRoomUsage  MerchandiseSales  \
# count         4018.000000      4018.000000       4018.000000
# mean             0.397529         0.338444        301.155244
# std              0.202773         0.178505         49.930111
# min              0.000000         0.000000        113.140000
# 25%              0.230000         0.200000        266.802500
# 50%              0.380000         0.320000        301.300000
# 75%              0.540000         0.460000        335.180000
# max              0.960000         0.920000        491.660000
#
#        OnlineBookingRate  LandscapingQuality  TournamentPreparations  \
# count        4018.000000         4018.000000             4018.000000
# mean            0.715438            0.498524                1.001244
# std             0.157714            0.288928                0.999252
# min             0.120000            0.000000                0.000000
# 25%             0.610000            0.250000                0.000000
# 50%             0.740000            0.500000                1.000000
# 75%             0.840000            0.750000                2.000000
# max             0.990000            1.000000                3.000000
#
#        GolfCourseVisitorCount  TeeTimeUtilization  CourseWetnessLevel  \
# count             4018.000000         4018.000000         4018.000000
# mean                80.104032           60.169617            0.284002
# std                  9.055640           19.870660            0.161077
# min                 53.000000            3.160000            0.000000
# 25%                 74.000000           46.020000            0.160000
# 50%                 80.000000           61.750000            0.260000
# 75%                 86.000000           75.697500            0.390000
# max                115.000000           98.850000            0.900000
#
#        GolfLessonAttendance  MerchandiseInventoryTurnover  ParkingLotUsage  \
# count           4018.000000                   4018.000000      4018.000000
# mean              20.084121                      1.242867        50.346274
# std                4.508216                      0.433510        22.488098
# min                7.000000                      0.500000         0.350000
# 25%               17.000000                      0.870000        33.432500
# 50%               20.000000                      1.220000        50.635000
# 75%               23.000000                      1.620000        68.015000
# max               40.000000                      2.000000        99.840000
#
#        CaddieServiceUsage  RestaurantBarRevenue  InflationRate2011  \
# count         4018.000000           4018.000000        4018.000000
# mean             0.401078            804.856807           0.100530
# std              0.202807            391.558151           0.057941
# min              0.000000              0.000000          -0.000616
# 25%              0.250000            537.052500           0.048462
# 50%              0.390000            806.995000           0.100271
# 75%              0.540000           1062.605000           0.152783
# max              0.970000           2222.540000           0.202587
#
#           Spending
# count  4018.000000
# mean   1238.975772
# std     677.517564
# min     178.820000
# 25%     766.332500
# 50%    1087.105000
# 75%    1533.607500
# max    7494.290000

# %% [markdown]
# ## ⑤　Preprocessing Pipeline

# %%
numerical_cols = X_train.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X_train.select_dtypes(include=['object', 'category']).columns

preprocessor = ColumnTransformer([
    ('std', StandardScaler(), numerical_cols),
    ('ohe', OneHotEncoder(), categorical_cols)
    ], remainder='passthrough')

# %% [markdown]
# ## ⑥　Training Pipeline

# %%
# ② Pipeline: Preprocess, VotingRegressor
training_pipeline = make_pipeline(
    preprocessor,
    VotingRegressor(estimators=[
        ('rf', RandomForestRegressor()),
        ('adaboost', AdaBoostRegressor()),
        ('lr', LinearRegression()),
        ('knn', KNeighborsRegressor())
        # Add more regression models if needed
    ])
)

# %% [markdown]
# ## ⑦　Hyperparameter Tuning

# %%
# ③ Define the parameter space
param_grid = {
    'votingregressor__rf__n_estimators': [10, 50, 100],
    'votingregressor__rf__max_depth': [None, 10, 20],
    'votingregressor__adaboost__n_estimators': [50, 100, 200],
    'votingregressor__adaboost__learning_rate': [0.01, 0.1, 0.5, 1.0],
    'votingregressor__lr__fit_intercept': [True, False],
    'votingregressor__knn__n_neighbors': [3, 5, 10],
    'votingregressor__knn__weights': ['uniform', 'distance']
    # Add other hyperparameters for the base models
}

# ④ Use RandomizedSearchCV for hyperparameter tuning
random_search = RandomizedSearchCV(training_pipeline,
                                   param_distributions=param_grid,
                                   n_iter=12,
                                   scoring='r2',
                                   cv=KFold(n_splits=15),
                                  n_jobs=-1
                                  )
random_search.fit(X_train, y_train)

# Perform the search
#random_search.fit(pd.df_train(X_train), y_train)

# Tuning Results
print("Best parameters:\n", random_search.best_params_)
print("\nBest score:\n", -random_search.best_score_)
# Out:
# Best parameters:
#  {'votingregressor__rf__n_estimators': 100, 'votingregressor__rf__max_depth': 10, 'votingregressor__lr__fit_intercept': True, 'votingregressor__knn__weights': 'uniform', 'votingregressor__knn__n_neighbors': 10, 'votingregressor__adaboost__n_estimators': 100, 'votingregressor__adaboost__learning_rate': 0.1}
#
# Best score:
#  -0.877391304193

# %% [markdown]
# ## ⑧　Cross-Validation with Best Parameters

# %%
# Extract best parameters and update the pipeline
training_pipeline.set_params(**random_search.best_params_)

# Perform cross-validation to check Performance
kf = KFold(n_splits=5)
scores = cross_val_score(training_pipeline, X_train, y_train, cv=kf, scoring='neg_mean_absolute_percentage_error')

print(f"MAPE: {-scores.mean().round(4)} ± {2*scores.std().round(4)}")
# Out:
# MAPE: 0.1516 ± 0.0154

# %% [markdown]
# ## ⑨　Making Predictions on Test Data

# %%
# Load the test dataset
test_url  = "/kaggle/input/prediction-of-golf-course-spending/test.csv"
df_test = pd.read_csv(test_url, index_col=0)

X_test = df_test.copy()

# Fit the model to the training set
training_pipeline.fit(X_train,y_train)

# Make Prediction of the Unseen Data
y_pred = training_pipeline.predict(X_test)

# %% [markdown]
# ## ⑩　Submitting the Prediction

# %%
# Make DataFrame for Submission
submission = pd.DataFrame(y_pred, index=df_test.index, columns=[target_col])

# Make a CSV file for Submission
submission.to_csv('submission.csv')

submission
# Out:
#                Spending
# Date
# 2022-01-01  1391.412026
# 2022-01-02  1240.595902
# 2022-01-03   769.807973
# 2022-01-04  1071.211100
# 2022-01-05  1085.861287
# ...                 ...
# 2023-12-27   688.874917
# 2023-12-28   737.215902
# 2023-12-29   663.440538
# 2023-12-30  1321.142973
# 2023-12-31  1209.520302
#
# [730 rows x 1 columns]
