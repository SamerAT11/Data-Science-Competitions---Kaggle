# %%
# !pip install lightning
# Out:
# Collecting lightning
#   Downloading lightning-2.2.4-py3-none-any.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 715.5 kB/s eta 0:00:00
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /opt/conda/lib/python3.10/site-packages (from lightning) (6.0.1)
# Requirement already satisfied: fsspec<2025.0,>=2022.5.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning) (2024.2.0)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /opt/conda/lib/python3.10/site-packages (from lightning) (0.11.2)
# Requirement already satisfied: numpy<3.0,>=1.17.2 in /opt/conda/lib/python3.10/site-packages (from lightning) (1.26.4)
# Requirement already satisfied: packaging<25.0,>=20.0 in /opt/conda/lib/python3.10/site-packages (from lightning) (21.3)
# Requirement already satisfied: torch<4.0,>=1.13.0 in /opt/conda/lib/python3.10/site-packages (from lightning) (2.1.2)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from lightning) (1.3.2)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /opt/conda/lib/python3.10/site-packages (from lightning) (4.66.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /opt/conda/lib/python3.10/site-packages (from lightning) (4.9.0)
# Requirement already satisfied: pytorch-lightning in /opt/conda/lib/python3.10/site-packages (from lightning) (2.2.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<2025.0,>=2022.5.0->lightning) (3.9.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from lightning-utilities<2.0,>=0.8.0->lightning) (69.0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging<25.0,>=20.0->lightning) (3.1.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch<4.0,>=1.13.0->lightning) (3.13.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch<4.0,>=1.13.0->lightning) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch<4.0,>=1.13.0->lightning) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch<4.0,>=1.13.0->lightning) (3.1.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch<4.0,>=1.13.0->lightning) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch<4.0,>=1.13.0->lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in /opt/conda/lib/python3.10/site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2025.0,>=2022.5.0->lightning) (3.6)
# Downloading lightning-2.2.4-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 8.6 MB/s eta 0:00:00
# Installing collected packages: lightning
# Successfully installed lightning-2.2.4

# %%
# Basic libraries
import os
import numpy
import torch
from torch import nn
import pandas
import matplotlib.pyplot as plt

# PyTorch data processing libraries
from torchvision import transforms, datasets
from torchvision.datasets import ImageFolder
from torch.utils.data import Dataset, DataLoader, random_split

# PyTorch Model Implementation Libraries
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.models as models
from torchmetrics import Accuracy

# PyTorch Lightning
from lightning import LightningDataModule, LightningModule
import lightning as L
from lightning.pytorch.callbacks.early_stopping import EarlyStopping
from lightning.pytorch.tuner import Tuner

# %%
# Set up train and test paths
data_path = '/kaggle/input/agricultural-crops-image-classification/Agricultural-crops'

# %%
class CropsDataModule(L.LightningDataModule):
    def __init__(self, data_dir: str, batch_size: int = 16):
        super().__init__()
        self.save_hyperparameters()
        self.data_dir = data_dir
        self.batch_size = batch_size
        self.base_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
        ])

    def setup(self, stage: str = None):
    # Use the ImageFolder method to arrange the dataset
        full_dataset = datasets.ImageFolder(root=self.data_dir, transform=self.base_transform)

        if stage == "fit" or stage is None:
            # Split for training and validation
            train_size = int(len(full_dataset) * 0.7)
            val_size = int(len(full_dataset) * 0.15)
            test_size = len(full_dataset) - train_size - val_size
            self.train_set, self.val_set, self.test_set = random_split(
                full_dataset, [train_size, val_size, test_size], generator=torch.Generator().manual_seed(42)
                )
            self.train_set.dataset.transform = transforms.Compose([
                transforms.RandomResizedCrop(224),
                transforms.RandomHorizontalFlip(),
                self.base_transform
            ])
            self.val_set.dataset.transform = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                self.base_transform
            ])

        if stage == "test" or stage == "predict" or stage is None:
            # Ensure the test set uses a less aggressive transformation
            self.test_set.dataset.transform = transforms.Compose([
                transforms.Resize(256),
                transforms.CenterCrop(224),
                self.base_transform
            ])

    def train_dataloader(self):
        return DataLoader(self.train_set, batch_size=self.batch_size, num_workers=4, shuffle=True)

    def val_dataloader(self):
        return DataLoader(self.val_set, batch_size=self.batch_size, num_workers=4)

    def test_dataloader(self):
        return DataLoader(self.test_set, batch_size=self.batch_size, num_workers=4)

# %%
# Create an instance of the data class
dm = CropsDataModule(data_dir=data_path, batch_size=32)

# %%
# Setup the data module
dm.setup()
train_loader = dm.train_dataloader()
val_loader = dm.val_dataloader()
test_loader = dm.test_dataloader()

# Function to check a few batches
def check_dataloader(dataloader, name):
    print(f"Checking {name} DataLoader:")
    for i, (data, target) in enumerate(dataloader):
        print(f"  Batch {i + 1}:")
        print(f"    Data shape: {data.shape}, Type: {data.dtype}")
        print(f"    Target shape: {target.shape}, Type: {target.dtype}")
        if i >= 2:  # Check only the first 3 batches
            break

check_dataloader(train_loader, "Training")
check_dataloader(val_loader, "Validation")
check_dataloader(test_loader, "Testing")
# Out:
# Checking Training DataLoader:
#   Batch 1:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
#   Batch 2:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
#   Batch 3:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
# Checking Validation DataLoader:
#   Batch 1:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
#   Batch 2:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
#   Batch 3:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
# Checking Testing DataLoader:
#   Batch 1:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
#   Batch 2:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64
#   Batch 3:
#     Data shape: torch.Size([32, 3, 224, 224]), Type: torch.float32
#     Target shape: torch.Size([32]), Type: torch.int64

# %%
class ImageNetTL(L.LightningModule):
    def __init__(self, num_target_classes: int, learning_rate: float = 0.001):
        super().__init__()
        self.save_hyperparameters()  # This saves learning_rate and num_target_classes as part of model hyperparameters
        self.learning_rate = learning_rate
        self.validation_step_outputs = [] # Create an empty list to store the validation step outputs
        self.test_step_outputs = []
        
        backbone = models.resnet50(weights="DEFAULT")
        num_features = backbone.fc.in_features # Save the features of the last layer
        layers = list(backbone.children())[:-1] # Remove the last layer
        self.feature_extractor = nn.Sequential(*layers) # Wrap the remaining layers
        
        self.num_target_classes = num_target_classes
        self.classifier = nn.Linear(num_features, num_target_classes)
        
        # Evaluation metrics
        self.train_acc = Accuracy(task='multiclass', num_classes=num_target_classes)
        self.valid_acc = Accuracy(task='multiclass', num_classes=num_target_classes)
        self.test_acc = Accuracy(task='multiclass', num_classes=num_target_classes)
        
    def forward(self, x):
        representations = self.feature_extractor(x).flatten(1)
        return self.classifier(representations)
    
    def training_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        loss = F.cross_entropy(preds, y)
        self.train_acc(preds, y)
        
        self.log('train_loss', loss, on_step=False, on_epoch=True, prog_bar=True)
        train_acc_val = self.train_acc.compute()
        self.log('train_acc', train_acc_val, on_step=False, on_epoch=True, prog_bar=True)
        return {'loss': loss, 'train_acc': train_acc_val}
    
    def validation_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        val_loss = F.cross_entropy(preds, y)
        self.valid_acc(preds, y)
        self.validation_step_outputs.append(val_loss)
        self.log('val_loss', val_loss, on_step=False, on_epoch=True)
        return {'val_loss': val_loss}
    
    # Added to make use of the outputs from each `validation_step`
    def on_validation_epoch_end(self):
        loss_average = torch.stack(self.validation_step_outputs).mean()
        self.log("validation_loss_average", loss_average)
        self.validation_step_outputs.clear()  # free memory
    
    def test_step(self, batch, batch_idx):
        x, y = batch
        preds = self(x)
        test_loss = F.cross_entropy(preds, y)
        self.test_step_outputs.append(test_loss)
        self.log("test_loss", test_loss, on_step=False, on_epoch=True)
        return {'test_loss': test_loss}
    
    # Added to make use of the outputs from each `test_step`
    def on_test_epoch_end(self):
        loss_average = torch.stack(self.test_step_outputs).mean()
        self.log("test_loss_average", loss_average)
        self.test_step_outputs.clear()  # free memory
        
    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=self.hparams.learning_rate)

# %%
model = ImageNetTL(num_target_classes=30)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 151MB/s]

# %%
# Run the model once quickly to check if everything is good
trainer = L.Trainer(fast_dev_run=True) # By default it runs (5 batches of train, validation, and test)
# Out:
# INFO: Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# INFO: Running in `fast_dev_run` mode: will run the requested loop using 1 batch(es). Logging and checkpointing is suppressed.

# %%
# Run a sanity check in the validation loop
trainer = L.Trainer(num_sanity_val_steps=2)
# Out:
# INFO: Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs

# %%
# Initialize EarlyStopping callback to monitor 'val_loss' for a patience of 3 epochs
early_stop_callback = EarlyStopping(
    monitor='val_loss',
    min_delta=0.00,
    patience=3,
    verbose=False,
    mode='min'
)

trainer = L.Trainer(max_epochs=20,
                    profiler='simple', log_every_n_steps=10, callbacks=early_stop_callback)

# Use SOTA tuners to tune batch size and lr
tuner = Tuner(trainer)
#tuner.scale_batch_size(model, dm, mode='power', batch_arg_name='batch_size')
tuner.lr_find(model, dm)
# Profiler is added to check if there are bottlenecks in the code
trainer.fit(model, datamodule=dm)
# Out:
# INFO: Trainer will use only 1 of 2 GPUs because it is running inside an interactive / notebook environment. You may try to set `Trainer(devices=2)` but please note that multi-GPU inside interactive / notebook environments is considered experimental and unstable. Your mileage may vary.
# INFO: GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO: IPU available: False, using: 0 IPUs
# INFO: HPU available: False, using: 0 HPUs
# WARNING: Missing logger folder: /kaggle/working/lightning_logs
# 2024-05-07 07:12:13.612811: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-07 07:12:13.612929: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-07 07:12:13.897268: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# INFO: `Trainer.fit` stopped: `max_steps=100` reached.
# INFO: Learning rate set to 0.0019054607179632484
# INFO: Restoring states from the checkpoint path at /kaggle/working/.lr_find_e7cda261-62fa-4b7f-9dae-d7f685c13e3a.ckpt
# INFO: Restored all states from the checkpoint at /kaggle/working/.lr_find_e7cda261-62fa-4b7f-9dae-d7f685c13e3a.ckpt
# INFO: FIT Profiler Report
#
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                  	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                   	|  -              	|  2882           	|  57.884         	|  100 %          	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  [Callback]LearningRateFinder.on_fit_start                                                                                                               	|  41.392         	|  1              	|  41.392         	|  71.508         	|
# |  run_training_epoch                                                                                                                                      	|  6.7937         	|  6              	|  40.762         	|  70.421         	|
# |  [Callback]_LRCallback.on_train_batch_end                                                                                                                	|  0.16354        	|  100            	|  16.354         	|  28.254         	|
# |  run_training_batch                                                                                                                                      	|  0.11397        	|  100            	|  11.397         	|  19.69          	|
# |  [LightningModule]ImageNetTL.optimizer_step                                                                                                              	|  0.11365        	|  100            	|  11.365         	|  19.635         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                            	|  0.086382       	|  100            	|  8.6382         	|  14.923         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                          	|  0.14542        	|  24             	|  3.49           	|  6.0293         	|
# |  [_EvaluationLoop].val_next                                                                                                                              	|  0.13695        	|  24             	|  3.2868         	|  5.6782         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                              	|  0.029069       	|  100            	|  2.9069         	|  5.0219         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                 	|  0.018761       	|  100            	|  1.8761         	|  3.2411         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                          	|  0.0058783      	|  124            	|  0.72891        	|  1.2593         	|
# |  [LightningModule]ImageNetTL.transfer_batch_to_device                                                                                                    	|  0.0057288      	|  124            	|  0.71037        	|  1.2272         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup             	|  0.15223        	|  1              	|  0.15223        	|  0.26299        	|
# |  [LightningModule]ImageNetTL.optimizer_zero_grad                                                                                                         	|  0.00084023     	|  100            	|  0.084023       	|  0.14516        	|
# |  [LightningDataModule]CropsDataModule.setup                                                                                                              	|  0.046387       	|  1              	|  0.046387       	|  0.080139       	|
# |  [LightningModule]ImageNetTL.on_validation_epoch_end                                                                                                     	|  0.005107       	|  6              	|  0.030642       	|  0.052937       	|
# |  [Callback]_LRCallback.on_train_batch_start                                                                                                              	|  0.00018751     	|  100            	|  0.018751       	|  0.032395       	|
# |  [LightningModule]ImageNetTL.on_validation_model_eval                                                                                                    	|  0.0019524      	|  6              	|  0.011714       	|  0.020238       	|
# |  [LightningModule]ImageNetTL.on_validation_model_zero_grad                                                                                               	|  0.0016277      	|  6              	|  0.0097662      	|  0.016872       	|
# |  [LightningModule]ImageNetTL.configure_gradient_clipping                                                                                                 	|  4.2675e-05     	|  100            	|  0.0042675      	|  0.0073725      	|
# |  [LightningModule]ImageNetTL.lr_scheduler_step                                                                                                           	|  3.2644e-05     	|  100            	|  0.0032644      	|  0.0056395      	|
# |  [LightningModule]ImageNetTL.configure_optimizers                                                                                                        	|  0.0012539      	|  1              	|  0.0012539      	|  0.0021663      	|
# |  [LightningDataModule]CropsDataModule.val_dataloader                                                                                                     	|  0.00092994     	|  1              	|  0.00092994     	|  0.0016066      	|
# |  [Callback]_LRCallback.on_after_backward                                                                                                                 	|  5.7733e-06     	|  100            	|  0.00057733     	|  0.00099739     	|
# |  [LightningModule]ImageNetTL.on_before_batch_transfer                                                                                                    	|  4.1506e-06     	|  124            	|  0.00051468     	|  0.00088916     	|
# |  [LightningDataModule]CropsDataModule.train_dataloader                                                                                                   	|  0.00048345     	|  1              	|  0.00048345     	|  0.00083521     	|
# |  [Callback]_LRCallback.on_before_zero_grad                                                                                                               	|  4.262e-06      	|  100            	|  0.0004262      	|  0.00073631     	|
# |  [Callback]_LRCallback.on_before_backward                                                                                                                	|  3.4847e-06     	|  100            	|  0.00034847     	|  0.00060201     	|
# |  [Callback]_LRCallback.on_before_optimizer_step                                                                                                          	|  3.1953e-06     	|  100            	|  0.00031953     	|  0.00055201     	|
# |  [LightningModule]ImageNetTL.on_train_batch_start                                                                                                        	|  3.0311e-06     	|  100            	|  0.00030311     	|  0.00052364     	|
# |  [LightningModule]ImageNetTL.on_after_batch_transfer                                                                                                     	|  2.3743e-06     	|  124            	|  0.00029441     	|  0.00050862     	|
# |  [LightningModule]ImageNetTL.on_before_zero_grad                                                                                                         	|  2.8961e-06     	|  100            	|  0.00028961     	|  0.00050033     	|
# |  [LightningModule]ImageNetTL.on_train_batch_end                                                                                                          	|  2.8759e-06     	|  100            	|  0.00028759     	|  0.00049683     	|
# |  [LightningModule]ImageNetTL.on_before_backward                                                                                                          	|  2.6802e-06     	|  100            	|  0.00026802     	|  0.00046303     	|
# |  [LightningModule]ImageNetTL.on_after_backward                                                                                                           	|  2.5618e-06     	|  100            	|  0.00025618     	|  0.00044258     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                     	|  2.1258e-06     	|  100            	|  0.00021258     	|  0.00036724     	|
# |  [LightningModule]ImageNetTL.on_before_optimizer_step                                                                                                    	|  1.8711e-06     	|  100            	|  0.00018711     	|  0.00032324     	|
# |  [Callback]_LRCallback.on_validation_start                                                                                                               	|  2.2503e-05     	|  6              	|  0.00013502     	|  0.00023326     	|
# |  [Callback]_LRCallback.on_validation_batch_end                                                                                                           	|  3.94e-06       	|  24             	|  9.4559e-05     	|  0.00016336     	|
# |  [Callback]_LRCallback.on_validation_batch_start                                                                                                         	|  3.485e-06      	|  24             	|  8.3641e-05     	|  0.0001445      	|
# |  [LightningModule]ImageNetTL.on_validation_batch_end                                                                                                     	|  2.2763e-06     	|  24             	|  5.4632e-05     	|  9.4382e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_batch_start                                                                                                   	|  2.1498e-06     	|  24             	|  5.1594e-05     	|  8.9134e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                      	|  7.4502e-06     	|  6              	|  4.4701e-05     	|  7.7225e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_start                                                                                                         	|  6.9035e-06     	|  6              	|  4.1421e-05     	|  7.1559e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_epoch_start                                                                                                   	|  6.7068e-06     	|  6              	|  4.0241e-05     	|  6.952e-05      	|
# |  [Callback]_LRCallback.on_train_epoch_end                                                                                                                	|  4.0145e-06     	|  6              	|  2.4087e-05     	|  4.1613e-05     	|
# |  [Callback]_LRCallback.on_train_epoch_start                                                                                                              	|  3.8188e-06     	|  6              	|  2.2913e-05     	|  3.9584e-05     	|
# |  [Callback]_LRCallback.on_validation_epoch_end                                                                                                           	|  3.5695e-06     	|  6              	|  2.1417e-05     	|  3.7e-05        	|
# |  [Callback]_LRCallback.on_validation_end                                                                                                                 	|  3.2885e-06     	|  6              	|  1.9731e-05     	|  3.4087e-05     	|
# |  [Callback]_LRCallback.on_validation_epoch_start                                                                                                         	|  3.2852e-06     	|  6              	|  1.9711e-05     	|  3.4053e-05     	|
# |  [LightningModule]ImageNetTL.on_train_epoch_start                                                                                                        	|  2.4662e-06     	|  6              	|  1.4797e-05     	|  2.5563e-05     	|
# |  [Callback]LearningRateFinder.on_load_checkpoint                                                                                                         	|  1.411e-05      	|  1              	|  1.411e-05      	|  2.4376e-05     	|
# |  [LightningModule]ImageNetTL.on_train_epoch_end                                                                                                          	|  1.8652e-06     	|  6              	|  1.1191e-05     	|  1.9334e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_end                                                                                                           	|  1.741e-06      	|  6              	|  1.0446e-05     	|  1.8046e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                         	|  1.0435e-05     	|  1              	|  1.0435e-05     	|  1.8027e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                        	|  1.6652e-06     	|  6              	|  9.991e-06      	|  1.726e-05      	|
# |  [Callback]_LRCallback.on_train_start                                                                                                                    	|  8.988e-06      	|  1              	|  8.988e-06      	|  1.5528e-05     	|
# |  [LightningModule]ImageNetTL.on_train_start                                                                                                              	|  6.349e-06      	|  1              	|  6.349e-06      	|  1.0968e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                           	|  6.212e-06      	|  1              	|  6.212e-06      	|  1.0732e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                     	|  5.335e-06      	|  1              	|  5.335e-06      	|  9.2167e-06     	|
# |  [Callback]_LRCallback.on_train_end                                                                                                                      	|  4.948e-06      	|  1              	|  4.948e-06      	|  8.5481e-06     	|
# |  [LightningModule]ImageNetTL.on_load_checkpoint                                                                                                          	|  4.708e-06      	|  1              	|  4.708e-06      	|  8.1335e-06     	|
# |  [LightningDataModule]CropsDataModule.prepare_data                                                                                                       	|  4.638e-06      	|  1              	|  4.638e-06      	|  8.0126e-06     	|
# |  [Callback]LearningRateFinder.setup                                                                                                                      	|  4.302e-06      	|  1              	|  4.302e-06      	|  7.4321e-06     	|
# |  [LightningModule]ImageNetTL.configure_callbacks                                                                                                         	|  4.227e-06      	|  1              	|  4.227e-06      	|  7.3025e-06     	|
# |  [LightningDataModule]CropsDataModule.state_dict                                                                                                         	|  4.032e-06      	|  1              	|  4.032e-06      	|  6.9657e-06     	|
# |  [LightningDataModule]CropsDataModule.teardown                                                                                                           	|  3.163e-06      	|  1              	|  3.163e-06      	|  5.4644e-06     	|
# |  [Callback]LearningRateFinder.teardown                                                                                                                   	|  3.139e-06      	|  1              	|  3.139e-06      	|  5.4229e-06     	|
# |  [Callback]LearningRateFinder.on_save_checkpoint                                                                                                         	|  3.11e-06       	|  1              	|  3.11e-06       	|  5.3728e-06     	|
# |  [LightningModule]ImageNetTL.setup                                                                                                                       	|  3.064e-06      	|  1              	|  3.064e-06      	|  5.2933e-06     	|
# |  [LightningModule]ImageNetTL.on_train_end                                                                                                                	|  2.87e-06       	|  1              	|  2.87e-06       	|  4.9582e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                             	|  2.614e-06      	|  1              	|  2.614e-06      	|  4.5159e-06     	|
# |  [Callback]ModelSummary.on_load_checkpoint                                                                                                               	|  2.464e-06      	|  1              	|  2.464e-06      	|  4.2568e-06     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                            	|  2.379e-06      	|  1              	|  2.379e-06      	|  4.1099e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown          	|  2.375e-06      	|  1              	|  2.375e-06      	|  4.103e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                  	|  2.291e-06      	|  1              	|  2.291e-06      	|  3.9579e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                            	|  2.256e-06      	|  1              	|  2.256e-06      	|  3.8975e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_load_checkpoint                                                                        	|  2.208e-06      	|  1              	|  2.208e-06      	|  3.8145e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_load_checkpoint	|  2.173e-06      	|  1              	|  2.173e-06      	|  3.7541e-06     	|
# |  [Callback]TQDMProgressBar.on_load_checkpoint                                                                                                            	|  2.163e-06      	|  1              	|  2.163e-06      	|  3.7368e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint	|  2.144e-06      	|  1              	|  2.144e-06      	|  3.704e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                        	|  2.047e-06      	|  1              	|  2.047e-06      	|  3.5364e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                      	|  2.039e-06      	|  1              	|  2.039e-06      	|  3.5226e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                         	|  2.023e-06      	|  1              	|  2.023e-06      	|  3.4949e-06     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                               	|  1.922e-06      	|  1              	|  1.922e-06      	|  3.3204e-06     	|
# |  [LightningModule]ImageNetTL.prepare_data                                                                                                                	|  1.803e-06      	|  1              	|  1.803e-06      	|  3.1149e-06     	|
# |  [LightningModule]ImageNetTL.teardown                                                                                                                    	|  1.583e-06      	|  1              	|  1.583e-06      	|  2.7348e-06     	|
# |  [LightningModule]ImageNetTL.on_save_checkpoint                                                                                                          	|  1.406e-06      	|  1              	|  1.406e-06      	|  2.429e-06      	|
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# INFO:
#   | Name              | Type               | Params
# ---------------------------------------------------------
# 0 | feature_extractor | Sequential         | 23.5 M
# 1 | classifier        | Linear             | 61.5 K
# 2 | train_acc         | MulticlassAccuracy | 0
# 3 | valid_acc         | MulticlassAccuracy | 0
# 4 | test_acc          | MulticlassAccuracy | 0
# ---------------------------------------------------------
# 23.6 M    Trainable params
# 0         Non-trainable params
# 23.6 M    Total params
# 94.278    Total estimated model params size (MB)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Training: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# INFO: FIT Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                         	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                          	|  -              	|  8403           	|  108.51         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                             	|  7.0248         	|  12             	|  84.297         	|  77.688         	|
# |  [Callback]LearningRateFinder.on_fit_start                                                                                                                      	|  41.392         	|  1              	|  41.392         	|  38.146         	|
# |  run_training_batch                                                                                                                                             	|  0.1096         	|  214            	|  23.455         	|  21.616         	|
# |  [LightningModule]ImageNetTL.optimizer_step                                                                                                                     	|  0.1093         	|  214            	|  23.391         	|  21.557         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                 	|  0.076667       	|  264            	|  20.24          	|  18.653         	|
# |  [LightningModule]ImageNetTL.transfer_batch_to_device                                                                                                           	|  0.07651        	|  264            	|  20.199         	|  18.615         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                   	|  0.086343       	|  214            	|  18.477         	|  17.029         	|
# |  [Callback]_LRCallback.on_train_batch_end                                                                                                                       	|  0.16354        	|  100            	|  16.354         	|  15.072         	|
# |  [_EvaluationLoop].val_next                                                                                                                                     	|  0.14182        	|  50             	|  7.0908         	|  6.5348         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                     	|  0.029293       	|  214            	|  6.2687         	|  5.7772         	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                 	|  0.11203        	|  50             	|  5.6015         	|  5.1623         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.81926        	|  6              	|  4.9156         	|  4.5301         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                        	|  0.015317       	|  214            	|  3.2779         	|  3.0209         	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                   	|  0.0025705      	|  114            	|  0.29304        	|  0.27007        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                  	|  0.036765       	|  7              	|  0.25736        	|  0.23718        	|
# |  [LightningModule]ImageNetTL.optimizer_zero_grad                                                                                                                	|  0.00081583     	|  214            	|  0.17459        	|  0.1609         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.07621        	|  2              	|  0.15242        	|  0.14047        	|
# |  [LightningDataModule]CropsDataModule.setup                                                                                                                     	|  0.043544       	|  2              	|  0.087088       	|  0.080259       	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                       	|  0.072997       	|  1              	|  0.072997       	|  0.067274       	|
# |  [LightningModule]ImageNetTL.on_validation_epoch_end                                                                                                            	|  0.0030501      	|  13             	|  0.039651       	|  0.036543       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                            	|  0.0013818      	|  26             	|  0.035926       	|  0.033109       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                              	|  0.001127       	|  26             	|  0.029303       	|  0.027005       	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                	|  0.028807       	|  1              	|  0.028807       	|  0.026549       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                               	|  0.0047394      	|  6              	|  0.028436       	|  0.026207       	|
# |  [LightningModule]ImageNetTL.on_validation_model_zero_grad                                                                                                      	|  0.0021962      	|  12             	|  0.026354       	|  0.024288       	|
# |  [LightningModule]ImageNetTL.on_validation_model_eval                                                                                                           	|  0.0019076      	|  13             	|  0.024799       	|  0.022855       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                 	|  0.0035803      	|  6              	|  0.021482       	|  0.019797       	|
# |  [Callback]_LRCallback.on_train_batch_start                                                                                                                     	|  0.00018751     	|  100            	|  0.018751       	|  0.017281       	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                            	|  0.013789       	|  1              	|  0.013789       	|  0.012708       	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                    	|  0.0013533      	|  7              	|  0.0094728      	|  0.0087301      	|
# |  [LightningModule]ImageNetTL.configure_gradient_clipping                                                                                                        	|  4.197e-05      	|  214            	|  0.0089816      	|  0.0082774      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  5.2463e-05     	|  114            	|  0.0059807      	|  0.0055118      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                   	|  0.00091556     	|  6              	|  0.0054934      	|  0.0050627      	|
# |  [LightningModule]ImageNetTL.lr_scheduler_step                                                                                                                  	|  3.2644e-05     	|  100            	|  0.0032644      	|  0.0030084      	|
# |  [LightningModule]ImageNetTL.configure_optimizers                                                                                                               	|  0.0012618      	|  2              	|  0.0025236      	|  0.0023257      	|
# |  [LightningDataModule]CropsDataModule.val_dataloader                                                                                                            	|  0.00071574     	|  2              	|  0.0014315      	|  0.0013192      	|
# |  [LightningDataModule]CropsDataModule.train_dataloader                                                                                                          	|  0.00052943     	|  2              	|  0.0010589      	|  0.00097584     	|
# |  [LightningModule]ImageNetTL.on_before_batch_transfer                                                                                                           	|  3.7343e-06     	|  264            	|  0.00098586     	|  0.00090856     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                         	|  0.00075635     	|  1              	|  0.00075635     	|  0.00069705     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                             	|  6.3383e-06     	|  114            	|  0.00072257     	|  0.00066591     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                	|  6.0949e-06     	|  114            	|  0.00069482     	|  0.00064034     	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                      	|  6.0345e-06     	|  114            	|  0.00068794     	|  0.000634       	|
# |  [LightningModule]ImageNetTL.on_after_batch_transfer                                                                                                            	|  2.5206e-06     	|  264            	|  0.00066545     	|  0.00061327     	|
# |  [LightningModule]ImageNetTL.on_train_batch_start                                                                                                               	|  2.8959e-06     	|  214            	|  0.00061972     	|  0.00057113     	|
# |  [LightningModule]ImageNetTL.on_before_zero_grad                                                                                                                	|  2.7489e-06     	|  214            	|  0.00058826     	|  0.00054214     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  8.3588e-05     	|  7              	|  0.00058511     	|  0.00053924     	|
# |  [LightningModule]ImageNetTL.on_after_backward                                                                                                                  	|  2.7044e-06     	|  214            	|  0.00057874     	|  0.00053337     	|
# |  [Callback]_LRCallback.on_after_backward                                                                                                                        	|  5.7733e-06     	|  100            	|  0.00057733     	|  0.00053206     	|
# |  [LightningModule]ImageNetTL.on_train_batch_end                                                                                                                 	|  2.6029e-06     	|  214            	|  0.00055703     	|  0.00051335     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                              	|  4.8742e-06     	|  114            	|  0.00055566     	|  0.00051209     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                               	|  4.5255e-06     	|  114            	|  0.0005159      	|  0.00047546     	|
# |  [LightningModule]ImageNetTL.on_before_backward                                                                                                                 	|  2.3126e-06     	|  214            	|  0.0004949      	|  0.0004561      	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                            	|  2.1163e-06     	|  214            	|  0.00045288     	|  0.00041737     	|
# |  [Callback]_LRCallback.on_before_zero_grad                                                                                                                      	|  4.262e-06      	|  100            	|  0.0004262      	|  0.00039279     	|
# |  [LightningModule]ImageNetTL.on_before_optimizer_step                                                                                                           	|  1.8089e-06     	|  214            	|  0.0003871      	|  0.00035674     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                               	|  3.3776e-06     	|  114            	|  0.00038505     	|  0.00035486     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                         	|  3.1154e-06     	|  114            	|  0.00035515     	|  0.00032731     	|
# |  [Callback]_LRCallback.on_before_backward                                                                                                                       	|  3.4847e-06     	|  100            	|  0.00034847     	|  0.00032115     	|
# |  [Callback]_LRCallback.on_before_optimizer_step                                                                                                                 	|  3.1953e-06     	|  100            	|  0.00031953     	|  0.00029447     	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                    	|  2.7597e-06     	|  114            	|  0.0003146      	|  0.00028994     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  2.7491e-06     	|  114            	|  0.0003134      	|  0.00028882     	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                    	|  2.7479e-06     	|  114            	|  0.00031326     	|  0.0002887      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  2.7467e-06     	|  114            	|  0.00031312     	|  0.00028857     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                     	|  2.5643e-06     	|  114            	|  0.00029233     	|  0.00026941     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                  	|  2.5563e-06     	|  114            	|  0.00029142     	|  0.00026857     	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                 	|  2.5296e-06     	|  114            	|  0.00028838     	|  0.00026577     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  2.4855e-06     	|  114            	|  0.00028334     	|  0.00026113     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                      	|  2.4612e-06     	|  114            	|  0.00028058     	|  0.00025858     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  2.4552e-06     	|  114            	|  0.00027989     	|  0.00025795     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                             	|  2.4245e-06     	|  114            	|  0.00027639     	|  0.00025472     	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                	|  2.3627e-06     	|  114            	|  0.00026935     	|  0.00024823     	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                   	|  2.3295e-06     	|  114            	|  0.00026556     	|  0.00024474     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  2.3069e-06     	|  114            	|  0.00026298     	|  0.00024236     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                       	|  2.2424e-06     	|  114            	|  0.00025563     	|  0.00023559     	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                 	|  6.4069e-06     	|  26             	|  0.00016658     	|  0.00015352     	|
# |  [Callback]_LRCallback.on_validation_start                                                                                                                      	|  2.2503e-05     	|  6              	|  0.00013502     	|  0.00012443     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                          	|  4.3493e-06     	|  26             	|  0.00011308     	|  0.00010422     	|
# |  [LightningModule]ImageNetTL.on_validation_epoch_start                                                                                                          	|  8.6636e-06     	|  13             	|  0.00011263     	|  0.0001038      	|
# |  [LightningModule]ImageNetTL.on_validation_batch_end                                                                                                            	|  2.2098e-06     	|  50             	|  0.00011049     	|  0.00010183     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                             	|  8.4002e-06     	|  13             	|  0.0001092      	|  0.00010064     	|
# |  [LightningModule]ImageNetTL.on_validation_start                                                                                                                	|  8.2271e-06     	|  13             	|  0.00010695     	|  9.8566e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_batch_start                                                                                                          	|  2.0832e-06     	|  50             	|  0.00010416     	|  9.5995e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                              	|  1.4583e-05     	|  7              	|  0.00010208     	|  9.4075e-05     	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                               	|  3.8995e-06     	|  26             	|  0.00010139     	|  9.3439e-05     	|
# |  [Callback]_LRCallback.on_validation_batch_end                                                                                                                  	|  3.94e-06       	|  24             	|  9.4559e-05     	|  8.7145e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                        	|  3.2984e-06     	|  26             	|  8.5758e-05     	|  7.9034e-05     	|
# |  [Callback]_LRCallback.on_validation_batch_start                                                                                                                	|  3.485e-06      	|  24             	|  8.3641e-05     	|  7.7083e-05     	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                     	|  9.4133e-06     	|  7              	|  6.5893e-05     	|  6.0727e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  2.5066e-06     	|  26             	|  6.5171e-05     	|  6.0061e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  2.4095e-06     	|  26             	|  6.2648e-05     	|  5.7736e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                             	|  1.0243e-05     	|  6              	|  6.1459e-05     	|  5.664e-05      	|
# ...
# |  [Callback]_LRCallback.on_train_epoch_start                                                                                                                     	|  3.8188e-06     	|  6              	|  2.2913e-05     	|  2.1117e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                            	|  3.0904e-06     	|  7              	|  2.1633e-05     	|  1.9937e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                       	|  2.1589e-05     	|  1              	|  2.1589e-05     	|  1.9896e-05     	|
# |  [Callback]_LRCallback.on_validation_epoch_end                                                                                                                  	|  3.5695e-06     	|  6              	|  2.1417e-05     	|  1.9738e-05     	|
# |  [Callback]_LRCallback.on_validation_end                                                                                                                        	|  3.2885e-06     	|  6              	|  1.9731e-05     	|  1.8184e-05     	|
# |  [Callback]_LRCallback.on_validation_epoch_start                                                                                                                	|  3.2852e-06     	|  6              	|  1.9711e-05     	|  1.8166e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  2.7806e-06     	|  7              	|  1.9464e-05     	|  1.7938e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                               	|  2.7284e-06     	|  7              	|  1.9099e-05     	|  1.7602e-05     	|
# |  [LightningModule]ImageNetTL.on_train_start                                                                                                                     	|  9.3505e-06     	|  2              	|  1.8701e-05     	|  1.7235e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                 	|  2.6193e-06     	|  7              	|  1.8335e-05     	|  1.6897e-05     	|
# |  [LightningDataModule]CropsDataModule.state_dict                                                                                                                	|  2.4987e-06     	|  7              	|  1.7491e-05     	|  1.612e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  2.464e-06      	|  7              	|  1.7248e-05     	|  1.5896e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                   	|  2.3373e-06     	|  7              	|  1.6361e-05     	|  1.5078e-05     	|
# |  [LightningModule]ImageNetTL.on_train_end                                                                                                                       	|  8.137e-06      	|  2              	|  1.6274e-05     	|  1.4998e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                               	|  2.272e-06      	|  7              	|  1.5904e-05     	|  1.4657e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                              	|  2.1824e-06     	|  7              	|  1.5277e-05     	|  1.4079e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                            	|  7.5905e-06     	|  2              	|  1.5181e-05     	|  1.3991e-05     	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                      	|  2.1633e-06     	|  7              	|  1.5143e-05     	|  1.3956e-05     	|
# |  [Callback]LearningRateFinder.on_load_checkpoint                                                                                                                	|  1.411e-05      	|  1              	|  1.411e-05      	|  1.3004e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  1.9274e-06     	|  7              	|  1.3492e-05     	|  1.2434e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                  	|  6.652e-06      	|  2              	|  1.3304e-05     	|  1.2261e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  2.146e-06      	|  6              	|  1.2876e-05     	|  1.1866e-05     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                          	|  1.0819e-05     	|  1              	|  1.0819e-05     	|  9.9707e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  1.0572e-05     	|  1              	|  1.0572e-05     	|  9.7431e-06     	|
# |  [LightningModule]ImageNetTL.setup                                                                                                                              	|  5.2265e-06     	|  2              	|  1.0453e-05     	|  9.6334e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                    	|  5.095e-06      	|  2              	|  1.019e-05      	|  9.3911e-06     	|
# |  [LightningModule]ImageNetTL.on_save_checkpoint                                                                                                                 	|  1.3897e-06     	|  7              	|  9.728e-06      	|  8.9653e-06     	|
# |  [Callback]_LRCallback.on_train_start                                                                                                                           	|  8.988e-06      	|  1              	|  8.988e-06      	|  8.2833e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                   	|  8.576e-06      	|  1              	|  8.576e-06      	|  7.9036e-06     	|
# |  [Callback]ModelSummary.setup                                                                                                                                   	|  4.234e-06      	|  2              	|  8.468e-06      	|  7.8041e-06     	|
# |  [LightningModule]ImageNetTL.configure_callbacks                                                                                                                	|  3.778e-06      	|  2              	|  7.556e-06      	|  6.9636e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  7.495e-06      	|  1              	|  7.495e-06      	|  6.9074e-06     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                  	|  7.489e-06      	|  1              	|  7.489e-06      	|  6.9018e-06     	|
# |  [LightningDataModule]CropsDataModule.prepare_data                                                                                                              	|  3.611e-06      	|  2              	|  7.222e-06      	|  6.6558e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                            	|  5.672e-06      	|  1              	|  5.672e-06      	|  5.2273e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                            	|  5.631e-06      	|  1              	|  5.631e-06      	|  5.1895e-06     	|
# |  [LightningDataModule]CropsDataModule.teardown                                                                                                                  	|  2.7485e-06     	|  2              	|  5.497e-06      	|  5.066e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                     	|  5.137e-06      	|  1              	|  5.137e-06      	|  4.7342e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                              	|  5.035e-06      	|  1              	|  5.035e-06      	|  4.6402e-06     	|
# |  [Callback]_LRCallback.on_train_end                                                                                                                             	|  4.948e-06      	|  1              	|  4.948e-06      	|  4.5601e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                         	|  2.417e-06      	|  2              	|  4.834e-06      	|  4.455e-06      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                     	|  4.733e-06      	|  1              	|  4.733e-06      	|  4.3619e-06     	|
# |  [LightningModule]ImageNetTL.on_load_checkpoint                                                                                                                 	|  4.708e-06      	|  1              	|  4.708e-06      	|  4.3389e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  2.2715e-06     	|  2              	|  4.543e-06      	|  4.1868e-06     	|
# |  [Callback]LearningRateFinder.setup                                                                                                                             	|  4.302e-06      	|  1              	|  4.302e-06      	|  3.9647e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                             	|  2.087e-06      	|  2              	|  4.174e-06      	|  3.8467e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                	|  2.0685e-06     	|  2              	|  4.137e-06      	|  3.8126e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                         	|  3.182e-06      	|  1              	|  3.182e-06      	|  2.9325e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                           	|  3.166e-06      	|  1              	|  3.166e-06      	|  2.9178e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  3.157e-06      	|  1              	|  3.157e-06      	|  2.9095e-06     	|
# |  [Callback]LearningRateFinder.teardown                                                                                                                          	|  3.139e-06      	|  1              	|  3.139e-06      	|  2.8929e-06     	|
# |  [LightningModule]ImageNetTL.prepare_data                                                                                                                       	|  1.566e-06      	|  2              	|  3.132e-06      	|  2.8864e-06     	|
# |  [Callback]LearningRateFinder.on_save_checkpoint                                                                                                                	|  3.11e-06       	|  1              	|  3.11e-06       	|  2.8662e-06     	|
# |  [LightningModule]ImageNetTL.teardown                                                                                                                           	|  1.4865e-06     	|  2              	|  2.973e-06      	|  2.7399e-06     	|
# |  [LightningModule]ImageNetTL.on_fit_start                                                                                                                       	|  2.763e-06      	|  1              	|  2.763e-06      	|  2.5464e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  2.64e-06       	|  1              	|  2.64e-06       	|  2.433e-06      	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                              	|  2.638e-06      	|  1              	|  2.638e-06      	|  2.4312e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                     	|  2.5e-06        	|  1              	|  2.5e-06        	|  2.304e-06      	|
# |  [Callback]ModelSummary.on_load_checkpoint                                                                                                                      	|  2.464e-06      	|  1              	|  2.464e-06      	|  2.2708e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_load_checkpoint                                                                               	|  2.208e-06      	|  1              	|  2.208e-06      	|  2.0349e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_load_checkpoint       	|  2.173e-06      	|  1              	|  2.173e-06      	|  2.0026e-06     	|
# |  [Callback]TQDMProgressBar.on_load_checkpoint                                                                                                                   	|  2.163e-06      	|  1              	|  2.163e-06      	|  1.9934e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  2.163e-06      	|  1              	|  2.163e-06      	|  1.9934e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  2.032e-06      	|  1              	|  2.032e-06      	|  1.8727e-06     	|
# |  [LightningModule]ImageNetTL.on_fit_end                                                                                                                         	|  2.027e-06      	|  1              	|  2.027e-06      	|  1.8681e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
trainer.test(model, datamodule=dm)
# Out:
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Testing: |          | 0/? [00:00<?, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test_loss         │     6.009132385253906     │
# │     test_loss_average     │     6.021322727203369     │
# └───────────────────────────┴───────────────────────────┘
# INFO: TEST Profiler Report
#
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Action                                                                                                                                                         	|  Mean duration (s)	|  Num calls      	|  Total time (s) 	|  Percentage %   	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  Total                                                                                                                                                          	|  -              	|  8506           	|  109.94         	|  100 %          	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |  run_training_epoch                                                                                                                                             	|  7.0248         	|  12             	|  84.297         	|  76.677         	|
# |  [Callback]LearningRateFinder.on_fit_start                                                                                                                      	|  41.392         	|  1              	|  41.392         	|  37.65          	|
# |  run_training_batch                                                                                                                                             	|  0.1096         	|  214            	|  23.455         	|  21.335         	|
# |  [LightningModule]ImageNetTL.optimizer_step                                                                                                                     	|  0.1093         	|  214            	|  23.391         	|  21.276         	|
# |  [Strategy]SingleDeviceStrategy.batch_to_device                                                                                                                 	|  0.076395       	|  268            	|  20.474         	|  18.623         	|
# |  [LightningModule]ImageNetTL.transfer_batch_to_device                                                                                                           	|  0.076237       	|  268            	|  20.432         	|  18.585         	|
# |  [Strategy]SingleDeviceStrategy.training_step                                                                                                                   	|  0.086343       	|  214            	|  18.477         	|  16.807         	|
# |  [Callback]_LRCallback.on_train_batch_end                                                                                                                       	|  0.16354        	|  100            	|  16.354         	|  14.876         	|
# |  [_EvaluationLoop].val_next                                                                                                                                     	|  0.14182        	|  50             	|  7.0908         	|  6.4498         	|
# |  [_TrainingEpochLoop].train_dataloader_next                                                                                                                     	|  0.029293       	|  214            	|  6.2687         	|  5.702          	|
# |  [Strategy]SingleDeviceStrategy.validation_step                                                                                                                 	|  0.11203        	|  50             	|  5.6015         	|  5.0951         	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_end       	|  0.81926        	|  6              	|  4.9156         	|  4.4712         	|
# |  [Strategy]SingleDeviceStrategy.backward                                                                                                                        	|  0.015317       	|  214            	|  3.2779         	|  2.9816         	|
# |  [_EvaluationLoop].test_next                                                                                                                                    	|  0.14392        	|  4              	|  0.5757         	|  0.52366        	|
# |  [Callback]TQDMProgressBar.on_train_batch_end                                                                                                                   	|  0.0025705      	|  114            	|  0.29304        	|  0.26655        	|
# |  [Callback]TQDMProgressBar.on_validation_start                                                                                                                  	|  0.036765       	|  7              	|  0.25736        	|  0.23409        	|
# |  [LightningModule]ImageNetTL.optimizer_zero_grad                                                                                                                	|  0.00081583     	|  214            	|  0.17459        	|  0.15881        	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.setup                    	|  0.050841       	|  3              	|  0.15252        	|  0.13873        	|
# |  [LightningDataModule]CropsDataModule.setup                                                                                                                     	|  0.04518        	|  3              	|  0.13554        	|  0.12329        	|
# |  [Strategy]SingleDeviceStrategy.test_step                                                                                                                       	|  0.023308       	|  4              	|  0.093233       	|  0.084806       	|
# |  [Callback]TQDMProgressBar.on_train_start                                                                                                                       	|  0.072997       	|  1              	|  0.072997       	|  0.066399       	|
# |  [Callback]TQDMProgressBar.on_test_start                                                                                                                        	|  0.046773       	|  1              	|  0.046773       	|  0.042545       	|
# |  [LightningModule]ImageNetTL.on_validation_epoch_end                                                                                                            	|  0.0030501      	|  13             	|  0.039651       	|  0.036067       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_start                                                                                                            	|  0.0013818      	|  26             	|  0.035926       	|  0.032678       	|
# |  [Callback]TQDMProgressBar.on_validation_batch_end                                                                                                              	|  0.001127       	|  26             	|  0.029303       	|  0.026654       	|
# |  [Callback]TQDMProgressBar.on_sanity_check_start                                                                                                                	|  0.028807       	|  1              	|  0.028807       	|  0.026203       	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_end                                                                               	|  0.0047394      	|  6              	|  0.028436       	|  0.025866       	|
# |  [LightningModule]ImageNetTL.on_validation_model_zero_grad                                                                                                      	|  0.0021962      	|  12             	|  0.026354       	|  0.023972       	|
# |  [LightningModule]ImageNetTL.on_validation_model_eval                                                                                                           	|  0.0019076      	|  13             	|  0.024799       	|  0.022557       	|
# |  [Callback]TQDMProgressBar.on_train_epoch_start                                                                                                                 	|  0.0035803      	|  6              	|  0.021482       	|  0.01954        	|
# |  [Callback]_LRCallback.on_train_batch_start                                                                                                                     	|  0.00018751     	|  100            	|  0.018751       	|  0.017056       	|
# |  [Callback]ModelSummary.on_fit_start                                                                                                                            	|  0.013789       	|  1              	|  0.013789       	|  0.012543       	|
# |  [Callback]TQDMProgressBar.on_validation_end                                                                                                                    	|  0.0013533      	|  7              	|  0.0094728      	|  0.0086165      	|
# |  [LightningModule]ImageNetTL.configure_gradient_clipping                                                                                                        	|  4.197e-05      	|  214            	|  0.0089816      	|  0.0081697      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_end       	|  5.2463e-05     	|  114            	|  0.0059807      	|  0.0054401      	|
# |  [Callback]TQDMProgressBar.on_train_epoch_end                                                                                                                   	|  0.00091556     	|  6              	|  0.0054934      	|  0.0049968      	|
# |  [Callback]TQDMProgressBar.on_test_batch_end                                                                                                                    	|  0.0011993      	|  4              	|  0.0047973      	|  0.0043636      	|
# |  [LightningModule]ImageNetTL.on_test_model_eval                                                                                                                 	|  0.0037166      	|  1              	|  0.0037166      	|  0.0033806      	|
# |  [LightningModule]ImageNetTL.lr_scheduler_step                                                                                                                  	|  3.2644e-05     	|  100            	|  0.0032644      	|  0.0029693      	|
# |  [LightningModule]ImageNetTL.configure_optimizers                                                                                                               	|  0.0012618      	|  2              	|  0.0025236      	|  0.0022955      	|
# |  [LightningModule]ImageNetTL.on_test_epoch_end                                                                                                                  	|  0.0022126      	|  1              	|  0.0022126      	|  0.0020126      	|
# |  [Callback]TQDMProgressBar.on_test_batch_start                                                                                                                  	|  0.00037366     	|  4              	|  0.0014946      	|  0.0013595      	|
# |  [LightningDataModule]CropsDataModule.val_dataloader                                                                                                            	|  0.00071574     	|  2              	|  0.0014315      	|  0.0013021      	|
# |  [LightningDataModule]CropsDataModule.train_dataloader                                                                                                          	|  0.00052943     	|  2              	|  0.0010589      	|  0.00096315     	|
# |  [LightningModule]ImageNetTL.on_before_batch_transfer                                                                                                           	|  3.7296e-06     	|  268            	|  0.00099954     	|  0.00090918     	|
# |  [Callback]TQDMProgressBar.on_train_end                                                                                                                         	|  0.00075635     	|  1              	|  0.00075635     	|  0.00068798     	|
# |  [Callback]TQDMProgressBar.on_test_end                                                                                                                          	|  0.00074483     	|  1              	|  0.00074483     	|  0.0006775      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_start                                                                             	|  6.3383e-06     	|  114            	|  0.00072257     	|  0.00065725     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_after_backward                                                                                	|  6.0949e-06     	|  114            	|  0.00069482     	|  0.00063201     	|
# |  [Callback]ModelSummary.on_train_batch_end                                                                                                                      	|  6.0345e-06     	|  114            	|  0.00068794     	|  0.00062575     	|
# |  [LightningModule]ImageNetTL.on_after_batch_transfer                                                                                                            	|  2.5185e-06     	|  268            	|  0.00067497     	|  0.00061395     	|
# |  [LightningModule]ImageNetTL.on_train_batch_start                                                                                                               	|  2.8959e-06     	|  214            	|  0.00061972     	|  0.0005637      	|
# |  [LightningModule]ImageNetTL.on_before_zero_grad                                                                                                                	|  2.7489e-06     	|  214            	|  0.00058826     	|  0.00053509     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_end        	|  8.3588e-05     	|  7              	|  0.00058511     	|  0.00053222     	|
# |  [LightningModule]ImageNetTL.on_after_backward                                                                                                                  	|  2.7044e-06     	|  214            	|  0.00057874     	|  0.00052643     	|
# |  [Callback]_LRCallback.on_after_backward                                                                                                                        	|  5.7733e-06     	|  100            	|  0.00057733     	|  0.00052514     	|
# |  [LightningModule]ImageNetTL.on_train_batch_end                                                                                                                 	|  2.6029e-06     	|  214            	|  0.00055703     	|  0.00050667     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_zero_grad                                                                              	|  4.8742e-06     	|  114            	|  0.00055566     	|  0.00050543     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_batch_end                                                                               	|  4.5255e-06     	|  114            	|  0.0005159      	|  0.00046927     	|
# |  [LightningModule]ImageNetTL.on_before_backward                                                                                                                 	|  2.3126e-06     	|  214            	|  0.0004949      	|  0.00045017     	|
# |  [Strategy]SingleDeviceStrategy.on_train_batch_start                                                                                                            	|  2.1163e-06     	|  214            	|  0.00045288     	|  0.00041194     	|
# |  [Callback]_LRCallback.on_before_zero_grad                                                                                                                      	|  4.262e-06      	|  100            	|  0.0004262      	|  0.00038768     	|
# |  [LightningModule]ImageNetTL.on_before_optimizer_step                                                                                                           	|  1.8089e-06     	|  214            	|  0.0003871      	|  0.0003521      	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_backward                                                                               	|  3.3776e-06     	|  114            	|  0.00038505     	|  0.00035024     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_before_optimizer_step                                                                         	|  3.1154e-06     	|  114            	|  0.00035515     	|  0.00032305     	|
# |  [LightningDataModule]CropsDataModule.test_dataloader                                                                                                           	|  0.00035169     	|  1              	|  0.00035169     	|  0.0003199      	|
# |  [Callback]_LRCallback.on_before_backward                                                                                                                       	|  3.4847e-06     	|  100            	|  0.00034847     	|  0.00031697     	|
# |  [Callback]_LRCallback.on_before_optimizer_step                                                                                                                 	|  3.1953e-06     	|  100            	|  0.00031953     	|  0.00029064     	|
# |  [Callback]TQDMProgressBar.on_after_backward                                                                                                                    	|  2.7597e-06     	|  114            	|  0.0003146      	|  0.00028616     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_optimizer_step 	|  2.7491e-06     	|  114            	|  0.0003134      	|  0.00028507     	|
# |  [Callback]ModelSummary.on_train_batch_start                                                                                                                    	|  2.7479e-06     	|  114            	|  0.00031326     	|  0.00028495     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_batch_start     	|  2.7467e-06     	|  114            	|  0.00031312     	|  0.00028482     	|
# |  [Callback]ModelSummary.on_before_zero_grad                                                                                                                     	|  2.5643e-06     	|  114            	|  0.00029233     	|  0.00026591     	|
# |  [Callback]TQDMProgressBar.on_before_zero_grad                                                                                                                  	|  2.5563e-06     	|  114            	|  0.00029142     	|  0.00026508     	|
# |  [Callback]TQDMProgressBar.on_train_batch_start                                                                                                                 	|  2.5296e-06     	|  114            	|  0.00028838     	|  0.00026231     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_backward       	|  2.4855e-06     	|  114            	|  0.00028334     	|  0.00025773     	|
# |  [Callback]ModelSummary.on_before_backward                                                                                                                      	|  2.4612e-06     	|  114            	|  0.00028058     	|  0.00025522     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_after_backward        	|  2.4552e-06     	|  114            	|  0.00027989     	|  0.00025459     	|
# |  [Callback]TQDMProgressBar.on_before_optimizer_step                                                                                                             	|  2.4245e-06     	|  114            	|  0.00027639     	|  0.0002514      	|
# |  [Callback]ModelSummary.on_before_optimizer_step                                                                                                                	|  2.3627e-06     	|  114            	|  0.00026935     	|  0.000245       	|
# |  [Callback]TQDMProgressBar.on_before_backward                                                                                                                   	|  2.3295e-06     	|  114            	|  0.00026556     	|  0.00024155     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_before_zero_grad      	|  2.3069e-06     	|  114            	|  0.00026298     	|  0.00023921     	|
# |  [Callback]ModelSummary.on_after_backward                                                                                                                       	|  2.2424e-06     	|  114            	|  0.00025563     	|  0.00023252     	|
# |  [Callback]ModelSummary.on_validation_batch_end                                                                                                                 	|  6.4069e-06     	|  26             	|  0.00016658     	|  0.00015152     	|
# |  [Callback]_LRCallback.on_validation_start                                                                                                                      	|  2.2503e-05     	|  6              	|  0.00013502     	|  0.00012281     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_end                                                                          	|  4.3493e-06     	|  26             	|  0.00011308     	|  0.00010286     	|
# |  [LightningModule]ImageNetTL.on_validation_epoch_start                                                                                                          	|  8.6636e-06     	|  13             	|  0.00011263     	|  0.00010245     	|
# |  [LightningModule]ImageNetTL.on_validation_batch_end                                                                                                            	|  2.2098e-06     	|  50             	|  0.00011049     	|  0.0001005      	|
# |  [Strategy]SingleDeviceStrategy.on_validation_start                                                                                                             	|  8.4002e-06     	|  13             	|  0.0001092      	|  9.9331e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_start                                                                                                                	|  8.2271e-06     	|  13             	|  0.00010695     	|  9.7284e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_batch_start                                                                                                          	|  2.0832e-06     	|  50             	|  0.00010416     	|  9.4746e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_start                                                                              	|  1.4583e-05     	|  7              	|  0.00010208     	|  9.2851e-05     	|
# |  [Callback]ModelSummary.on_validation_batch_start                                                                                                               	|  3.8995e-06     	|  26             	|  0.00010139     	|  9.2223e-05     	|
# |  [Callback]_LRCallback.on_validation_batch_end                                                                                                                  	|  3.94e-06       	|  24             	|  9.4559e-05     	|  8.6011e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_batch_start                                                                        	|  3.2984e-06     	|  26             	|  8.5758e-05     	|  7.8006e-05     	|
# |  [Callback]_LRCallback.on_validation_batch_start                                                                                                                	|  3.485e-06      	|  24             	|  8.3641e-05     	|  7.608e-05      	|
# |  [Callback]ModelSummary.on_validation_start                                                                                                                     	|  9.4133e-06     	|  7              	|  6.5893e-05     	|  5.9937e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_start	|  2.5066e-06     	|  26             	|  6.5171e-05     	|  5.928e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_batch_end  	|  2.4095e-06     	|  26             	|  6.2648e-05     	|  5.6985e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_epoch_start                                                                             	|  1.0243e-05     	|  6              	|  6.1459e-05     	|  5.5904e-05     	|
# |  [LightningModule]ImageNetTL.on_train_epoch_end                                                                                                                 	|  5.0189e-06     	|  12             	|  6.0227e-05     	|  5.4783e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_end                                                                          	|  6.2139e-06     	|  7              	|  4.3497e-05     	|  3.9565e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_validation_end                                                                                                               	|  3.204e-06      	|  13             	|  4.1652e-05     	|  3.7887e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_end                                                                                	|  5.856e-06      	|  7              	|  4.0992e-05     	|  3.7287e-05     	|
# |  [LightningModule]ImageNetTL.on_validation_end                                                                                                                  	|  2.8955e-06     	|  13             	|  3.7642e-05     	|  3.4239e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_start                                                                                                                    	|  6.0432e-06     	|  6              	|  3.6259e-05     	|  3.2981e-05     	|
# |  [Callback]ModelSummary.on_validation_end                                                                                                                       	|  5.0959e-06     	|  7              	|  3.5671e-05     	|  3.2447e-05     	|
# |  [Callback]TQDMProgressBar.setup                                                                                                                                	|  1.134e-05      	|  3              	|  3.4021e-05     	|  3.0946e-05     	|
# |  [LightningModule]ImageNetTL.on_train_epoch_start                                                                                                               	|  2.6181e-06     	|  12             	|  3.1417e-05     	|  2.8577e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_start                                                                                   	|  3.0935e-05     	|  1              	|  3.0935e-05     	|  2.8139e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.setup                                                                                            	|  1.0104e-05     	|  3              	|  3.0313e-05     	|  2.7573e-05     	|
# |  [Callback]ModelSummary.on_train_epoch_end                                                                                                                      	|  4.6172e-06     	|  6              	|  2.7703e-05     	|  2.5199e-05     	|
# |  [Callback]ModelSummary.on_test_batch_end                                                                                                                       	|  6.5482e-06     	|  4              	|  2.6193e-05     	|  2.3825e-05     	|
# |  [Callback]_LRCallback.on_train_epoch_end                                                                                                                       	|  4.0145e-06     	|  6              	|  2.4087e-05     	|  2.191e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_start      	|  3.321e-06      	|  7              	|  2.3247e-05     	|  2.1146e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_validation_epoch_start                                                                        	|  3.2949e-06     	|  7              	|  2.3064e-05     	|  2.0979e-05     	|
# |  [Callback]_LRCallback.on_train_epoch_start                                                                                                                     	|  3.8188e-06     	|  6              	|  2.2913e-05     	|  2.0842e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_start                                                                                                            	|  3.0904e-06     	|  7              	|  2.1633e-05     	|  1.9678e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_end                                                                                       	|  2.1589e-05     	|  1              	|  2.1589e-05     	|  1.9637e-05     	|
# |  [Callback]_LRCallback.on_validation_epoch_end                                                                                                                  	|  3.5695e-06     	|  6              	|  2.1417e-05     	|  1.9481e-05     	|
# |  [Callback]_LRCallback.on_validation_end                                                                                                                        	|  3.2885e-06     	|  6              	|  1.9731e-05     	|  1.7947e-05     	|
# |  [Callback]_LRCallback.on_validation_epoch_start                                                                                                                	|  3.2852e-06     	|  6              	|  1.9711e-05     	|  1.7929e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_start	|  2.7806e-06     	|  7              	|  1.9464e-05     	|  1.7705e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_start                                                                                                               	|  2.7284e-06     	|  7              	|  1.9099e-05     	|  1.7373e-05     	|
# |  [LightningModule]ImageNetTL.on_train_start                                                                                                                     	|  9.3505e-06     	|  2              	|  1.8701e-05     	|  1.7011e-05     	|
# |  [Callback]ModelSummary.on_validation_epoch_end                                                                                                                 	|  2.6193e-06     	|  7              	|  1.8335e-05     	|  1.6678e-05     	|
# |  [LightningDataModule]CropsDataModule.state_dict                                                                                                                	|  2.4987e-06     	|  7              	|  1.7491e-05     	|  1.591e-05      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_validation_epoch_end  	|  2.464e-06      	|  7              	|  1.7248e-05     	|  1.5689e-05     	|
# |  [Callback]TQDMProgressBar.on_save_checkpoint                                                                                                                   	|  2.3373e-06     	|  7              	|  1.6361e-05     	|  1.4882e-05     	|
# |  [LightningModule]ImageNetTL.on_train_end                                                                                                                       	|  8.137e-06      	|  2              	|  1.6274e-05     	|  1.4803e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_save_checkpoint                                                                               	|  2.272e-06      	|  7              	|  1.5904e-05     	|  1.4466e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_end                                                                                	|  3.8585e-06     	|  4              	|  1.5434e-05     	|  1.4039e-05     	|
# |  [Callback]TQDMProgressBar.on_validation_epoch_end                                                                                                              	|  2.1824e-06     	|  7              	|  1.5277e-05     	|  1.3896e-05     	|
# |  [LightningModule]ImageNetTL.setup                                                                                                                              	|  5.09e-06       	|  3              	|  1.527e-05      	|  1.389e-05      	|
# |  [Callback]ModelSummary.on_save_checkpoint                                                                                                                      	|  2.1633e-06     	|  7              	|  1.5143e-05     	|  1.3774e-05     	|
# |  [Callback]ModelSummary.on_test_batch_start                                                                                                                     	|  3.5913e-06     	|  4              	|  1.4365e-05     	|  1.3066e-05     	|
# |  [Callback]LearningRateFinder.on_load_checkpoint                                                                                                                	|  1.411e-05      	|  1              	|  1.411e-05      	|  1.2835e-05     	|
# |  [Callback]ModelSummary.on_test_start                                                                                                                           	|  1.39e-05       	|  1              	|  1.39e-05       	|  1.2644e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_save_checkpoint       	|  1.9274e-06     	|  7              	|  1.3492e-05     	|  1.2272e-05     	|
# |  [Callback]ModelSummary.setup                                                                                                                                   	|  4.4847e-06     	|  3              	|  1.3454e-05     	|  1.2238e-05     	|
# |  [Strategy]SingleDeviceStrategy.on_train_start                                                                                                                  	|  6.652e-06      	|  2              	|  1.3304e-05     	|  1.2101e-05     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_epoch_start     	|  2.146e-06      	|  6              	|  1.2876e-05     	|  1.1712e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_batch_start                                                                              	|  3.1325e-06     	|  4              	|  1.253e-05      	|  1.1397e-05     	|
# |  [LightningModule]ImageNetTL.configure_callbacks                                                                                                                	|  4.1627e-06     	|  3              	|  1.2488e-05     	|  1.1359e-05     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_start                                                                                    	|  1.2442e-05     	|  1              	|  1.2442e-05     	|  1.1317e-05     	|
# |  [LightningModule]ImageNetTL.on_test_start                                                                                                                      	|  1.2086e-05     	|  1              	|  1.2086e-05     	|  1.0994e-05     	|
# |  [LightningModule]ImageNetTL.on_test_batch_start                                                                                                                	|  2.977e-06      	|  4              	|  1.1908e-05     	|  1.0832e-05     	|
# |  [LightningDataModule]CropsDataModule.teardown                                                                                                                  	|  3.862e-06      	|  3              	|  1.1586e-05     	|  1.0539e-05     	|
# |  [Callback]ModelSummary.on_train_start                                                                                                                          	|  1.0819e-05     	|  1              	|  1.0819e-05     	|  9.841e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_start           	|  1.0572e-05     	|  1              	|  1.0572e-05     	|  9.6164e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_train_end                                                                                                                    	|  5.095e-06      	|  2              	|  1.019e-05      	|  9.2689e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_end        	|  2.4907e-06     	|  4              	|  9.963e-06      	|  9.0624e-06     	|
# |  [LightningModule]ImageNetTL.on_save_checkpoint                                                                                                                 	|  1.3897e-06     	|  7              	|  9.728e-06      	|  8.8487e-06     	|
# |  [LightningDataModule]CropsDataModule.prepare_data                                                                                                              	|  3.0733e-06     	|  3              	|  9.22e-06       	|  8.3866e-06     	|
# |  [LightningModule]ImageNetTL.on_test_batch_end                                                                                                                  	|  2.2932e-06     	|  4              	|  9.173e-06      	|  8.3438e-06     	|
# |  [Callback]_LRCallback.on_train_start                                                                                                                           	|  8.988e-06      	|  1              	|  8.988e-06      	|  8.1755e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_start                                                                                                                   	|  8.576e-06      	|  1              	|  8.576e-06      	|  7.8008e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_batch_start      	|  2.1333e-06     	|  4              	|  8.533e-06      	|  7.7617e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.teardown                                                                                         	|  2.758e-06      	|  3              	|  8.274e-06      	|  7.5261e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_start             	|  7.495e-06      	|  1              	|  7.495e-06      	|  6.8175e-06     	|
# |  [Callback]TQDMProgressBar.on_sanity_check_end                                                                                                                  	|  7.489e-06      	|  1              	|  7.489e-06      	|  6.812e-06      	|
# |  [Strategy]SingleDeviceStrategy.on_test_start                                                                                                                   	|  7.108e-06      	|  1              	|  7.108e-06      	|  6.4655e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.teardown                 	|  2.256e-06      	|  3              	|  6.768e-06      	|  6.1562e-06     	|
# |  [Callback]TQDMProgressBar.teardown                                                                                                                             	|  2.208e-06      	|  3              	|  6.624e-06      	|  6.0252e-06     	|
# |  [Callback]ModelSummary.teardown                                                                                                                                	|  2.0997e-06     	|  3              	|  6.299e-06      	|  5.7296e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_start                                                                            	|  5.672e-06      	|  1              	|  5.672e-06      	|  5.1593e-06     	|
# |  [Callback]ModelSummary.on_train_end                                                                                                                            	|  5.631e-06      	|  1              	|  5.631e-06      	|  5.122e-06      	|
# |  [Callback]ModelSummary.on_test_end                                                                                                                             	|  5.38e-06       	|  1              	|  5.38e-06       	|  4.8937e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_train_end                                                                                     	|  5.137e-06      	|  1              	|  5.137e-06      	|  4.6726e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_sanity_check_end                                                                              	|  5.035e-06      	|  1              	|  5.035e-06      	|  4.5799e-06     	|
# |  [Callback]_LRCallback.on_train_end                                                                                                                             	|  4.948e-06      	|  1              	|  4.948e-06      	|  4.5007e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_fit_start                                                                                     	|  4.733e-06      	|  1              	|  4.733e-06      	|  4.3052e-06     	|
# |  [LightningModule]ImageNetTL.on_load_checkpoint                                                                                                                 	|  4.708e-06      	|  1              	|  4.708e-06      	|  4.2824e-06     	|
# |  [LightningModule]ImageNetTL.teardown                                                                                                                           	|  1.5343e-06     	|  3              	|  4.603e-06      	|  4.1869e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_end                                                                                      	|  4.516e-06      	|  1              	|  4.516e-06      	|  4.1078e-06     	|
# |  [LightningModule]ImageNetTL.prepare_data                                                                                                                       	|  1.476e-06      	|  3              	|  4.428e-06      	|  4.0277e-06     	|
# |  [Callback]LearningRateFinder.setup                                                                                                                             	|  4.302e-06      	|  1              	|  4.302e-06      	|  3.9131e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_end                                                                                	|  4.117e-06      	|  1              	|  4.117e-06      	|  3.7449e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_test_epoch_start                                                                              	|  3.759e-06      	|  1              	|  3.759e-06      	|  3.4192e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_start            	|  3.738e-06      	|  1              	|  3.738e-06      	|  3.4001e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_start                                                                                                                         	|  3.182e-06      	|  1              	|  3.182e-06      	|  2.8944e-06     	|
# |  [Callback]TQDMProgressBar.on_fit_end                                                                                                                           	|  3.166e-06      	|  1              	|  3.166e-06      	|  2.8798e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_start    	|  3.157e-06      	|  1              	|  3.157e-06      	|  2.8716e-06     	|
# |  [Callback]LearningRateFinder.teardown                                                                                                                          	|  3.139e-06      	|  1              	|  3.139e-06      	|  2.8553e-06     	|
# |  [Callback]LearningRateFinder.on_save_checkpoint                                                                                                                	|  3.11e-06       	|  1              	|  3.11e-06       	|  2.8289e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_start                                                                                                                     	|  3.08e-06       	|  1              	|  3.08e-06       	|  2.8016e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_start                                                                                                                  	|  2.801e-06      	|  1              	|  2.801e-06      	|  2.5478e-06     	|
# |  [LightningModule]ImageNetTL.on_fit_start                                                                                                                       	|  2.763e-06      	|  1              	|  2.763e-06      	|  2.5132e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_sanity_check_end      	|  2.64e-06       	|  1              	|  2.64e-06       	|  2.4014e-06     	|
# |  [Callback]ModelSummary.on_fit_end                                                                                                                              	|  2.638e-06      	|  1              	|  2.638e-06      	|  2.3995e-06     	|
# |  [Callback]ModelSummary.on_sanity_check_end                                                                                                                     	|  2.5e-06        	|  1              	|  2.5e-06        	|  2.274e-06      	|
# |  [Callback]ModelSummary.on_load_checkpoint                                                                                                                      	|  2.464e-06      	|  1              	|  2.464e-06      	|  2.2413e-06     	|
# |  [Callback]EarlyStopping{'monitor': 'val_loss', 'mode': 'min'}.on_load_checkpoint                                                                               	|  2.208e-06      	|  1              	|  2.208e-06      	|  2.0084e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_start      	|  2.189e-06      	|  1              	|  2.189e-06      	|  1.9911e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_load_checkpoint       	|  2.173e-06      	|  1              	|  2.173e-06      	|  1.9766e-06     	|
# |  [Callback]TQDMProgressBar.on_load_checkpoint                                                                                                                   	|  2.163e-06      	|  1              	|  2.163e-06      	|  1.9675e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_train_end             	|  2.163e-06      	|  1              	|  2.163e-06      	|  1.9675e-06     	|
# |  [Callback]TQDMProgressBar.on_test_epoch_end                                                                                                                    	|  2.124e-06      	|  1              	|  2.124e-06      	|  1.932e-06      	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_end              	|  2.041e-06      	|  1              	|  2.041e-06      	|  1.8565e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_fit_end               	|  2.032e-06      	|  1              	|  2.032e-06      	|  1.8483e-06     	|
# |  [LightningModule]ImageNetTL.on_fit_end                                                                                                                         	|  2.027e-06      	|  1              	|  2.027e-06      	|  1.8438e-06     	|
# |  [LightningModule]ImageNetTL.on_test_end                                                                                                                        	|  1.946e-06      	|  1              	|  1.946e-06      	|  1.7701e-06     	|
# |  [Callback]ModelSummary.on_test_epoch_end                                                                                                                       	|  1.931e-06      	|  1              	|  1.931e-06      	|  1.7565e-06     	|
# |  [LightningModule]ImageNetTL.on_test_epoch_start                                                                                                                	|  1.916e-06      	|  1              	|  1.916e-06      	|  1.7428e-06     	|
# |  [Callback]ModelCheckpoint{'monitor': None, 'mode': 'min', 'every_n_train_steps': 0, 'every_n_epochs': 1, 'train_time_interval': None}.on_test_epoch_end        	|  1.857e-06      	|  1              	|  1.857e-06      	|  1.6891e-06     	|
# |  [Strategy]SingleDeviceStrategy.on_test_end                                                                                                                     	|  1.58e-06       	|  1              	|  1.58e-06       	|  1.4372e-06     	|
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# [{'test_loss': 6.009132385253906, 'test_loss_average': 6.021322727203369}]

# %%
# Launch TensorBoard to display outputs
# %reload_ext tensorboard
# %tensorboard --logdir=/kaggle/working/lightning_logs
# Out:
#       <iframe id="tensorboard-frame-2ce2547c0bf99d5b" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-2ce2547c0bf99d5b");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
